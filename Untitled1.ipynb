# %% [markdown]
# <a href="https://colab.research.google.com/github/mafebelisario/hack-jam/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Create a complete 'annoying, funny, and over-complicated USF Class Registration login page' with the following features: a basic HTML structure including username/password fields, placeholders for login requirements, and containers for two authentication challenges; CSS styling using a green, gold, and white color scheme with general 'annoying' visual elements and a cumbersome layout; a section displaying alphabetically ordered login requirements (e.g., minimum length, special characters) that are visually prominent and obstructive; an image captcha component asking for 'weird things' (e.g., 'Select all images containing a single-celled organism riding a unicycle') from a provided set of images; a person role matching authentication challenge where users match person images to roles (e.g., 'Student' to 'Professor') from a collection of images and predefined roles; and JavaScript logic to handle the overall login flow, including username/password validation, checking alphabetical login requirements, and ensuring both the image captcha and person role matching challenges are successfully completed before allowing the user to 'log in'. The final output should be the complete HTML, CSS, and JavaScript code.

# %% [markdown]
# ## Generate HTML Structure
#
# ### Subtask:
# Create the basic HTML structure for the 'USF Class Registration' login page. This will include input fields for username and password, placeholders for login requirements, and containers for the two authentication challenges (image captcha and role matching).

# %% [markdown]
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>USF Class Registration Login - The Most Secure Page Ever!</title>
#     <style>
#         /* Basic styling for better readability - you can expand this later */
#         body { font-family: Arial, sans-serif; margin: 20px; background-color: #f4f4f4; }
#         .login-container { background-color: #fff; padding: 20px; border-radius: 8px; box-shadow: 0 0 10px rgba(0, 0, 0, 0.1); max-width: 500px; margin: auto; }
#         h1 { text-align: center; color: #333; }
#         .form-group { margin-bottom: 15px; }
#         .form-group label { display: block; margin-bottom: 5px; font-weight: bold; }
#         .form-group input[type="text"], .form-group input[type="password"] { width: calc(100% - 22px); padding: 10px; border: 1px solid #ddd; border-radius: 4px; }
#         .challenge-container, #login-requirements-container { border: 1px dashed #ccc; padding: 15px; margin-top: 20px; border-radius: 4px; background-color: #f9f9f9; text-align: center; color: #666; }
#         button { width: 100%; padding: 10px; background-color: #007bff; color: white; border: none; border-radius: 4px; cursor: pointer; font-size: 16px; margin-top: 20px; }
#         button:hover { background-color: #0056b3; }
#     </style>
# </head>
# <body>
#     <div class="login-container">
#         <h1>USF Class Registration Login</h1>
#
#         <form>
#             <div class="form-group">
#                 <label for="username">Username:</label>
#                 <input type="text" id="username" name="username" placeholder="Enter your username" required>
#             </div>
#             <div class="form-group">
#                 <label for="password">Password:</label>
#                 <input type="password" id="password" name="password" placeholder="Enter your password" required>
#             </div>
#
#             <div id="login-requirements-container" class="challenge-container">
#                 <p>Login Requirements Placeholder: Password must be 8+ chars, include uppercase, lowercase, number, and special character.</p>
#             </div>
#
#             <div id="captcha-challenge-container" class="challenge-container">
#                 <p>Image Captcha Challenge Placeholder</p>
#                 <!-- Example: <img src="captcha.png" alt="captcha image"> <input type="text" placeholder="Enter captcha"> -->
#             </div>
#
#             <div id="role-matching-challenge-container" class="challenge-container">
#                 <p>Role Matching Challenge Placeholder</p>
#                 <!-- Example: <p>Are you a Student or Faculty?</p> <select><option>Student</option><option>Faculty</option></select> -->
#             </div>
#
#             <button type="submit">Login</button>
#         </form>
#     </div>
# </body>
# </html>
# ```

# %% [markdown]
# ## Apply CSS Styling
#
# ### Subtask:
# Style the login page using CSS, incorporating the specified green, gold, and white color scheme. Implement general 'annoying' visual elements and ensure the layout is functional yet intentionally cumbersome.

# %% [markdown]
# **Reasoning**:
# To style the login page with the specified CSS rules, including the green, gold, and white color scheme, 'annoying' visual elements, and a cumbersome layout, I will generate a Python code block that creates an HTML file containing the login form and an embedded `<style>` block with all the defined CSS.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>
            <button type="submit">Proceed With Caution</button>
        </form>
    </div>
</body>
</html>
'''

# To display the HTML, you would typically save it to a file and open in a browser
# or in a Colab environment, use IPython.display.HTML
from IPython.display import HTML
display(HTML(html_content))

print("HTML content with CSS styling applied and displayed.")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
#             overflow: hidden; /* To prevent scrollbar from minor rotations */
#         }
#
#         .login-container {
#             background-color: #ffffff; /* White background for the container */
#             border: 5px solid #FCD116; /* USF Gold border */
#             border-radius: 0px; /* Sharp edges */
# ...

# %% [markdown]
# ## Implement Alphabetical Login Requirements
#
# ### Subtask:
# Add a section displaying various login requirements (e.g., minimum length, special characters, numbers, uppercase letters) and ensure they are dynamically or statically ordered alphabetically. Make these requirements visually prominent and perhaps slightly obstructive.

# %% [markdown]
# **Reasoning**:
# I need to modify the existing HTML content to include specific, alphabetically ordered login requirements within the `login-requirements-container` and apply CSS to make them visually prominent and obstructive, as specified in the subtask instructions. This will be done by updating the `html_content` variable in a Python code block.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul>
                    <li>At least one digit must be included.</li>
                    <li>At least one lowercase character is required.</li>
                    <li>At least one special character (!@#$%^&*) is mandatory.</li>
                    <li>At least one uppercase character is required.</li>
                    <li>Minimum length of 12 characters is enforced.</li>
                    <li>Must not contain common dictionary words.</li>
                    <li>Must not contain your username.</li>
                    <li>No sequential characters (e.g., 'abc', '123').</li>
                    <li>Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <button type="submit">Proceed With Caution</button>
        </form>
    </div>
</body>
</html>
'''

# To display the HTML, you would typically save it to a file and open in a browser
# or in a Colab environment, use IPython.display.HTML
from IPython.display import HTML
display(HTML(html_content))

print("HTML content with alphabetical login requirements and obstructive styling applied and displayed.")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
#             overflow: hidden; /* To prevent scrollbar from minor rotations */
#         }
#
#         .login-container {
#             background-color: #ffffff; /* White background for the container */
#             border: 5px solid #FCD116; /* USF Gold border */
#             border-radius: 0px; /* Sharp edges */
# ...

# %% [markdown]
# ## Develop Image Captcha
#
# ### Subtask:
# Create an image captcha component that presents users with a series of images and asks for 'weird things' (e.g., 'Select all images containing a single-celled organism riding a unicycle'). This will require a set of images and associated questions/answers.

# %% [markdown]
# **Reasoning**:
# I need to update the `html_content` to include the image captcha component within the `captcha-challenge-container` as specified. This involves adding the captcha question, a grid of placeholder images with checkboxes, a verification button, and corresponding CSS styling to make it prominent and annoying, then displaying the updated HTML.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

        /* Styling for Captcha Challenge Container */
        #captcha-challenge-container {
            background-color: #e0f2f1; /* Light green background */
            border: 4px dotted #FCD116; /* Gold dotted border */
            padding: 25px;
            margin-top: 40px;
            margin-bottom: 40px;
            border-radius: 15px;
            box-shadow: -8px 8px 12px rgba(0, 0, 0, 0.2); /* Offset shadow */
            font-size: 1.1em;
            color: #004d40; /* Darker green text */
            text-align: center;
            position: relative; /* For overlapping */
            left: -10px; /* Slightly off-center */
            transform: rotate(-3deg); /* Annoying tilt */
            z-index: 4; /* Higher z-index to overlap */
            animation: wiggle 0.5s infinite alternate; /* Subtle wiggling */
        }

        @keyframes wiggle {
            0% { transform: rotate(-3deg); }
            100% { transform: rotate(3deg); }
        }

        #captcha-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.4em;
            text-shadow: 1px 1px 0px #FCD116;
        }

        .captcha-grid {
            display: grid;
            grid-template-columns: repeat(3, 1fr); /* 3 columns */
            gap: 15px; /* Spacing between images */
            margin-top: 20px;
            margin-bottom: 20px;
            border: 2px dashed #006747; /* Green dashed border for the grid */
            padding: 10px;
            background-color: #fafafa;
        }

        .captcha-item {
            position: relative;
            border: 3px solid #ccc; /* Default border */
            cursor: pointer;
            overflow: hidden;
            transform: scale(0.98); /* Slightly smaller initially */
            transition: transform 0.2s ease-in-out, border-color 0.2s ease-in-out, box-shadow 0.2s ease-in-out;
        }

        .captcha-item:nth-child(even) { transform: rotate(1deg); } /* Annoying subtle rotation */
        .captcha-item:nth-child(odd) { transform: rotate(-1deg); }

        .captcha-item img {
            width: 100%;
            height: 120px; /* Fixed height for visual inconsistency */
            object-fit: cover;
            display: block;
            filter: grayscale(20%); /* Slightly desaturated */
        }

        .captcha-item input[type="checkbox"] {
            position: absolute;
            top: 5px;
            left: 5px;
            z-index: 10; /* Ensure checkbox is clickable */
            width: 25px;
            height: 25px;
            transform: scale(1.2); /* Larger checkbox */
            accent-color: #006747; /* Green checkbox */
            box-shadow: 0 0 0 3px #FCD116; /* Gold shadow on checkbox */
        }

        .captcha-item.selected {
            border-color: #006747; /* Green border when selected */
            box-shadow: 0 0 10px rgba(0, 103, 71, 0.5); /* Green glow */
            transform: scale(1.05) rotate(0deg) !important; /* Zoom and straighten on selection */
        }

        #verify-captcha-btn {
            background-color: #FCD116; /* Gold button */
            color: #006747; /* Green text */
            padding: 15px 30px;
            border: 2px solid #006747;
            border-radius: 5px;
            font-size: 1.1em;
            font-weight: bold;
            margin-top: 25px;
            width: auto; /* Not full width */
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.8;
            transition: all 0.3s ease;
            transform: skewX(-5deg); /* Annoying skew */
            position: relative;
        }

        #verify-captcha-btn:hover {
            background-color: #006747; /* Green on hover */
            color: #FCD116; /* Gold text */
            transform: skewX(5deg) scale(1.02); /* Reverse skew and slight scale */
            opacity: 1;
        }

        /* Styling for Role Matching Container (Placeholder for now, just to show position) */
        #role-matching-challenge-container {
            background-color: #fce4ec; /* Light pink background */
            border: 3px dashed #FCD116;
            padding: 20px;
            margin-top: 30px;
            border-radius: 10px;
            box-shadow: 0 0 8px rgba(0, 0, 0, 0.1);
            color: #c2185b;
            text-align: center;
            transform: rotate(1deg); /* Slight tilt */
            position: relative;
            z-index: 1;
        }



    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul>
                    <li>At least one digit must be included.</li>
                    <li>At least one lowercase character is required.</li>
                    <li>At least one special character (!@#$%^&*) is mandatory.</li>
                    <li>At least one uppercase character is required.</li>
                    <li>Minimum length of 12 characters is enforced.</li>
                    <li>Must not contain common dictionary words.</li>
                    <li>Must not contain your username.</li>
                    <li>No sequential characters (e.g., 'abc', '123').</li>
                    <li>Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <div id="captcha-challenge-container">
                <h3>Prove you are not a robot (or a very bored USF student) by selecting all images containing a single-celled organism riding a unicycle:</h3>
                <div class="captcha-grid">
                    <div class="captcha-item">
                        <input type="checkbox" id="img1" name="captcha-img" value="img1">
                        <img src="https://picsum.photos/id/60/150/150" alt="Abstract Image 1">
                        <label for="img1" style="display:none;">Select Image 1</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img2" name="captcha-img" value="img2">
                        <img src="https://picsum.photos/id/61/150/150" alt="Abstract Image 2">
                        <label for="img2" style="display:none;">Select Image 2</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img3" name="captcha-img" value="img3">
                        <img src="https://picsum.photos/id/62/150/150" alt="Abstract Image 3">
                        <label for="img3" style="display:none;">Select Image 3</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img4" name="captcha-img" value="img4">
                        <img src="https://picsum.photos/id/63/150/150" alt="Abstract Image 4">
                        <label for="img4" style="display:none;">Select Image 4</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img5" name="captcha-img" value="img5">
                        <img src="https://picsum.photos/id/64/150/150" alt="Abstract Image 5">
                        <label for="img5" style="display:none;">Select Image 5</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img6" name="captcha-img" value="img6">
                        <img src="https://picsum.photos/id/65/150/150" alt="Abstract Image 6">
                        <label for="img6" style="display:none;">Select Image 6</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img7" name="captcha-img" value="img7">
                        <img src="https://picsum.photos/id/66/150/150" alt="Abstract Image 7">
                        <label for="img7" style="display:none;">Select Image 7</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img8" name="captcha-img" value="img8">
                        <img src="https://picsum.photos/id/67/150/150" alt="Abstract Image 8">
                        <label for="img8" style="display:none;">Select Image 8</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img9" name="captcha-img" value="img9">
                        <img src="https://picsum.photos/id/68/150/150" alt="Abstract Image 9">
                        <label for="img9" style="display:none;">Select Image 9</label>
                    </div>
                </div>
                <button type="button" id="verify-captcha-btn">Verify Captcha (Good Luck!)</button>
            </div>

            <div id="role-matching-challenge-container">
                <p>Role Matching Challenge Placeholder</p>
            </div>

            <button type="submit">Proceed With Caution</button>
        </form>
    </div>
</body>
</html>
'''

# To display the HTML, use IPython.display.HTML
from IPython.display import HTML
display(HTML(html_content))

print("HTML content with image captcha component and obstructive styling applied and displayed.")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
#             overflow: hidden; /* To prevent scrollbar from minor rotations */
#         }
#
#         .login-container {
#             background-color: #ffffff; /* White background for the container */
#             border: 5px solid #FCD116; /* USF Gold border */
#             border-radius: 0px; /* Sharp edges */
# ...

# %% [markdown]
# ## Implement Person Role Matching Authentication
#
# ### Subtask:
# Develop a second authentication challenge where users must match person images to their correct roles (e.g., 'Match the image of a 'Student' to the correct 'Professor' role'). This will involve a collection of images and predefined roles.

# %% [markdown]
# **Reasoning**:
# I need to update the `html_content` variable to include the new 'Person Role Matching' authentication challenge with its specific HTML structure (instructions, image grid, role selection dropdowns, verify button) and incorporate new, annoying CSS styling as per the subtask instructions. This will involve replacing the placeholder content in the `role-matching-challenge-container`.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

        /* Styling for Captcha Challenge Container */
        #captcha-challenge-container {
            background-color: #e0f2f1; /* Light green background */
            border: 4px dotted #FCD116; /* Gold dotted border */
            padding: 25px;
            margin-top: 40px;
            margin-bottom: 40px;
            border-radius: 15px;
            box-shadow: -8px 8px 12px rgba(0, 0, 0, 0.2); /* Offset shadow */
            font-size: 1.1em;
            color: #004d40; /* Darker green text */
            text-align: center;
            position: relative; /* For overlapping */
            left: -10px; /* Slightly off-center */
            transform: rotate(-3deg); /* Annoying tilt */
            z-index: 4; /* Higher z-index to overlap */
            animation: wiggle 0.5s infinite alternate; /* Subtle wiggling */
        }

        @keyframes wiggle {
            0% { transform: rotate(-3deg); }
            100% { transform: rotate(3deg); }
        }

        #captcha-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.4em;
            text-shadow: 1px 1px 0px #FCD116;
        }

        .captcha-grid {
            display: grid;
            grid-template-columns: repeat(3, 1fr); /* 3 columns */
            gap: 15px; /* Spacing between images */
            margin-top: 20px;
            margin-bottom: 20px;
            border: 2px dashed #006747; /* Green dashed border for the grid */
            padding: 10px;
            background-color: #fafafa;
        }

        .captcha-item {
            position: relative;
            border: 3px solid #ccc; /* Default border */
            cursor: pointer;
            overflow: hidden;
            transform: scale(0.98); /* Slightly smaller initially */
            transition: transform 0.2s ease-in-out, border-color 0.2s ease-in-out, box-shadow 0.2s ease-in-out;
        }

        .captcha-item:nth-child(even) { transform: rotate(1deg); } /* Annoying subtle rotation */
        .captcha-item:nth-child(odd) { transform: rotate(-1deg); }

        .captcha-item img {
            width: 100%;
            height: 120px; /* Fixed height for visual inconsistency */
            object-fit: cover;
            display: block;
            filter: grayscale(20%); /* Slightly desaturated */
        }

        .captcha-item input[type="checkbox"] {
            position: absolute;
            top: 5px;
            left: 5px;
            z-index: 10; /* Ensure checkbox is clickable */
            width: 25px;
            height: 25px;
            transform: scale(1.2); /* Larger checkbox */
            accent-color: #006747; /* Green checkbox */
            box-shadow: 0 0 0 3px #FCD116; /* Gold shadow on checkbox */
        }

        .captcha-item.selected {
            border-color: #006747; /* Green border when selected */
            box-shadow: 0 0 10px rgba(0, 103, 71, 0.5); /* Green glow */
            transform: scale(1.05) rotate(0deg) !important; /* Zoom and straighten on selection */
        }

        #verify-captcha-btn {
            background-color: #FCD116; /* Gold button */
            color: #006747; /* Green text */
            padding: 15px 30px;
            border: 2px solid #006747;
            border-radius: 5px;
            font-size: 1.1em;
            font-weight: bold;
            margin-top: 25px;
            width: auto; /* Not full width */
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.8;
            transition: all 0.3s ease;
            transform: skewX(-5deg); /* Annoying skew */
            position: relative;
        }

        #verify-captcha-btn:hover {
            background-color: #006747; /* Green on hover */
            color: #FCD116; /* Gold text */
            transform: skewX(5deg) scale(1.02); /* Reverse skew and slight scale */
            opacity: 1;
        }

        /* Styling for Role Matching Container */
        #role-matching-challenge-container {
            background-color: #F0F8FF; /* AliceBlue background for contrast */
            border: 6px double #006747; /* Double green border */
            padding: 30px;
            margin-top: 50px;
            margin-bottom: 50px;
            border-radius: 20px;
            box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; /* Gold and Red offset shadows */
            font-size: 1.2em;
            color: #333333;
            text-align: center;
            position: relative; /* For overlapping and positioning */
            left: 15px; /* Intentionally offset */
            transform: rotate(4deg); /* Significant tilt */
            z-index: 5; /* Highest z-index to be most prominent */
            animation: pulse-shadow 3s infinite alternate;
        }

        @keyframes pulse-shadow {
            0% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
            50% { box-shadow: -15px -15px 0px 0px rgba(0,0,0,0.5), 15px 15px 0px 0px rgba(0,0,0,0.5); }
            100% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
        }

        #role-matching-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.6em;
            text-shadow: 2px 2px 0px #FCD116;
            font-family: 'Impact', sans-serif; /* Aggressive font */
            line-height: 1.3;
        }

        .role-matching-grid {
            display: grid;
            grid-template-columns: repeat(2, 1fr); /* 2 columns to make it more spread out */
            gap: 25px; /* Large gap */
            margin-top: 30px;
            margin-bottom: 30px;
            border: 3px ridge #FCD116; /* Ridge border */
            padding: 20px;
            background-color: #FAFAF0; /* Very light yellow */
            box-shadow: inset 0 0 10px rgba(0, 103, 71, 0.2);
            transform: skewY(1deg); /* Slight skew to the grid itself */
        }

        .person-card {
            border: 2px dashed #006747; /* Dashed green border */
            padding: 15px;
            background-color: #FFFFFF;
            box-shadow: 5px 5px 8px rgba(0, 0, 0, 0.15);
            text-align: center;
            transition: transform 0.3s ease-in-out;
            transform: rotate(calc(var(--rotation-deg) * 1deg)); /* Variable rotation for each card */
            position: relative;
        }

        .person-card:nth-child(odd) { --rotation-deg: -2; }
        .person-card:nth-child(even) { --rotation-deg: 2; }

        .person-card:hover {
            transform: scale(1.05) rotate(0deg); /* Straighten and zoom on hover */
            box-shadow: 0 0 15px #FCD116;
            border-color: #FCD116; /* Gold border on hover */
        }

        .person-card img {
            width: 100%;
            max-width: 150px; /* Consistent image size */
            height: 150px;
            object-fit: cover;
            border: 3px solid #FCD116; /* Gold border for image */
            border-radius: 50%; /* Make images circular */
            margin-bottom: 15px;
            filter: saturate(150%); /* Over-saturated images */
            animation: image-glow 2s infinite alternate;
        }

        @keyframes image-glow {
            0% { box-shadow: 0 0 5px #FCD116; }
            100% { box-shadow: 0 0 15px #FCD116, 0 0 20px #006747; }
        }

        .role-select {
            width: 80%;
            padding: 10px;
            margin-top: 10px;
            border: 2px solid #006747; /* Green border */
            border-radius: 5px;
            background-color: #E6FFE6; /* Light green background */
            font-size: 1em;
            font-family: 'Courier New', monospace; /* Annoying font for dropdown */
            color: #003300;
            cursor: pointer;
            appearance: none; /* Remove default arrow */
            background-image: url('data:image/svg+xml;charset=US-ASCII,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%22292.4%22%20height%3D%22292.4%22%3E%3Cpath%20fill%3D%22%23006747%22%20d%3D%22M287%2069.9a14.6%2014.6%200%200%200-20.7%200L146.2%20189.9%2026.1%2069.9a14.6%2014.6%200%200%200-20.7%2020.7l130.8%20130.9a14.6%2014.6%200%200%200%2020.7%200L287%2090.6a14.6%2014.6%200%200%200%200-20.7z%22%2F%3E%3C%2Fsvg%3E');
            background-repeat: no-repeat;
            background-position: right 10px top 50%;
            background-size: 16px;
            padding-right: 30px; /* Space for custom arrow */
        }

        .role-select:focus {
            outline: none;
            border-color: #FCD116;
            box-shadow: 0 0 0 3px rgba(252, 209, 22, 0.5);
        }

        #verify-role-btn {
            background-color: #006747; /* Green button */
            color: #FCD116; /* Gold text */
            padding: 20px 40px;
            border: 3px solid #FCD116; /* Gold border */
            border-radius: 10px;
            font-size: 1.3em;
            font-weight: bold;
            margin-top: 30px;
            width: auto;
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.7;
            transition: all 0.4s ease;
            transform: rotate(-5deg); /* Another annoying tilt */
            letter-spacing: 2px; /* Spaced out text */
        }

        #verify-role-btn:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text */
            transform: rotate(5deg) scale(1.03); /* Reverse tilt and scale */
            opacity: 1;
            box-shadow: 0 0 20px rgba(0, 103, 71, 0.7);
        }





    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul>
                    <li>At least one digit must be included.</li>
                    <li>At least one lowercase character is required.</li>
                    <li>At least one special character (!@#$%^&*) is mandatory.</li>
                    <li>At least one uppercase character is required.</li>
                    <li>Minimum length of 12 characters is enforced.</li>
                    <li>Must not contain common dictionary words.</li>
                    <li>Must not contain your username.</li>
                    <li>No sequential characters (e.g., 'abc', '123').</li>
                    <li>Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <div id="captcha-challenge-container">
                <h3>Prove you are not a robot (or a very bored USF student) by selecting all images containing a single-celled organism riding a unicycle:</h3>
                <div class="captcha-grid">
                    <div class="captcha-item">
                        <input type="checkbox" id="img1" name="captcha-img" value="img1">
                        <img src="https://picsum.photos/id/60/150/150" alt="Abstract Image 1">
                        <label for="img1" style="display:none;">Select Image 1</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img2" name="captcha-img" value="img2">
                        <img src="https://picsum.photos/id/61/150/150" alt="Abstract Image 2">
                        <label for="img2" style="display:none;">Select Image 2</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img3" name="captcha-img" value="img3">
                        <img src="https://picsum.photos/id/62/150/150" alt="Abstract Image 3">
                        <label for="img3" style="display:none;">Select Image 3</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img4" name="captcha-img" value="img4">
                        <img src="https://picsum.photos/id/63/150/150" alt="Abstract Image 4">
                        <label for="img4" style="display:none;">Select Image 4</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img5" name="captcha-img" value="img5">
                        <img src="https://picsum.photos/id/64/150/150" alt="Abstract Image 5">
                        <label for="img5" style="display:none;">Select Image 5</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img6" name="captcha-img" value="img6">
                        <img src="https://picsum.photos/id/65/150/150" alt="Abstract Image 6">
                        <label for="img6" style="display:none;">Select Image 6</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img7" name="captcha-img" value="img7">
                        <img src="https://picsum.photos/id/66/150/150" alt="Abstract Image 7">
                        <label for="img7" style="display:none;">Select Image 7</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img8" name="captcha-img" value="img8">
                        <img src="https://picsum.photos/id/67/150/150" alt="Abstract Image 8">
                        <label for="img8" style="display:none;">Select Image 8</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img9" name="captcha-img" value="img9">
                        <img src="https://picsum.photos/id/68/150/150" alt="Abstract Image 9">
                        <label for="img9" style="display:none;">Select Image 9</label>
                    </div>
                </div>
                <button type="button" id="verify-captcha-btn">Verify Captcha (Good Luck!)</button>
            </div>

            <div id="role-matching-challenge-container">
                <h3>Match the individual to their highly classified USF role. Misclicking will result in academic probation!</h3>
                <div class="role-matching-grid">
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1005/150/150" alt="Person 1">
                        <select class="role-select" name="person1-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1011/150/150" alt="Person 2">
                        <select class="role-select" name="person2-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1025/150/150" alt="Person 3">
                        <select class="role-select" name="person3-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1027/150/150" alt="Person 4">
                        <select class="role-select" name="person4-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                </div>
                <button type="button" id="verify-role-btn">Verify Role Matches</button>
            </div>

            <button type="submit">Proceed With Caution</button>
        </form>
    </div>
</body>
</html>
'''

from IPython.display import HTML
display(HTML(html_content))

print("HTML content with person role matching challenge and obstructive styling applied and displayed.")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
#             overflow: hidden; /* To prevent scrollbar from minor rotations */
#         }
#
#         .login-container {
#             background-color: #ffffff; /* White background for the container */
#             border: 5px solid #FCD116; /* USF Gold border */
#             border-radius: 0px; /* Sharp edges */
# ...

# %% [markdown]
# ## Integrate Login Logic and Interactivity
#
# ### Subtask:
# Add JavaScript logic to handle the entire login flow, including client-side username/password validation, dynamically checking alphabetical login requirements, verifying the image captcha, and ensuring the person role matching challenge is completed. All conditions must be met before allowing a 'log in' action.

# %% [markdown]
# **Reasoning**:
# I need to add a `<script>` tag to the existing HTML content and inside it, add JavaScript code to get references to all relevant HTML elements. This is the foundational step for implementing the login logic, validation, and interactivity as outlined in the subtask instructions.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

        /* Styling for Captcha Challenge Container */
        #captcha-challenge-container {
            background-color: #e0f2f1; /* Light green background */
            border: 4px dotted #FCD116; /* Gold dotted border */
            padding: 25px;
            margin-top: 40px;
            margin-bottom: 40px;
            border-radius: 15px;
            box-shadow: -8px 8px 12px rgba(0, 0, 0, 0.2); /* Offset shadow */
            font-size: 1.1em;
            color: #004d40; /* Darker green text */
            text-align: center;
            position: relative; /* For overlapping */
            left: -10px; /* Slightly off-center */
            transform: rotate(-3deg); /* Annoying tilt */
            z-index: 4; /* Higher z-index to overlap */
            animation: wiggle 0.5s infinite alternate; /* Subtle wiggling */
        }

        @keyframes wiggle {
            0% { transform: rotate(-3deg); }
            100% { transform: rotate(3deg); }
        }

        #captcha-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.4em;
            text-shadow: 1px 1px 0px #FCD116;
        }

        .captcha-grid {
            display: grid;
            grid-template-columns: repeat(3, 1fr); /* 3 columns */
            gap: 15px; /* Spacing between images */
            margin-top: 20px;
            margin-bottom: 20px;
            border: 2px dashed #006747; /* Green dashed border for the grid */
            padding: 10px;
            background-color: #fafafa;
        }

        .captcha-item {
            position: relative;
            border: 3px solid #ccc; /* Default border */
            cursor: pointer;
            overflow: hidden;
            transform: scale(0.98); /* Slightly smaller initially */
            transition: transform 0.2s ease-in-out, border-color 0.2s ease-in-out, box-shadow 0.2s ease-in-out;
        }

        .captcha-item:nth-child(even) { transform: rotate(1deg); } /* Annoying subtle rotation */
        .captcha-item:nth-child(odd) { transform: rotate(-1deg); }

        .captcha-item img {
            width: 100%;
            height: 120px; /* Fixed height for visual inconsistency */
            object-fit: cover;
            display: block;
            filter: grayscale(20%); /* Slightly desaturated */
        }

        .captcha-item input[type="checkbox"] {
            position: absolute;
            top: 5px;
            left: 5px;
            z-index: 10; /* Ensure checkbox is clickable */
            width: 25px;
            height: 25px;
            transform: scale(1.2); /* Larger checkbox */
            accent-color: #006747; /* Green checkbox */
            box-shadow: 0 0 0 3px #FCD116; /* Gold shadow on checkbox */
        }

        .captcha-item.selected {
            border-color: #006747; /* Green border when selected */
            box-shadow: 0 0 10px rgba(0, 103, 71, 0.5); /* Green glow */
            transform: scale(1.05) rotate(0deg) !important; /* Zoom and straighten on selection */
        }

        #verify-captcha-btn {
            background-color: #FCD116; /* Gold button */
            color: #006747; /* Green text */
            padding: 15px 30px;
            border: 2px solid #006747;
            border-radius: 5px;
            font-size: 1.1em;
            font-weight: bold;
            margin-top: 25px;
            width: auto; /* Not full width */
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.8;
            transition: all 0.3s ease;
            transform: skewX(-5deg); /* Annoying skew */
            position: relative;
        }

        #verify-captcha-btn:hover {
            background-color: #006747; /* Green on hover */
            color: #FCD116; /* Gold text */
            transform: skewX(5deg) scale(1.02); /* Reverse skew and slight scale */
            opacity: 1;
        }

        /* Styling for Role Matching Container */
        #role-matching-challenge-container {
            background-color: #F0F8FF; /* AliceBlue background for contrast */
            border: 6px double #006747; /* Double green border */
            padding: 30px;
            margin-top: 50px;
            margin-bottom: 50px;
            border-radius: 20px;
            box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; /* Gold and Red offset shadows */
            font-size: 1.2em;
            color: #333333;
            text-align: center;
            position: relative; /* For overlapping and positioning */
            left: 15px; /* Intentionally offset */
            transform: rotate(4deg); /* Significant tilt */
            z-index: 5; /* Highest z-index to be most prominent */
            animation: pulse-shadow 3s infinite alternate;
        }

        @keyframes pulse-shadow {
            0% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
            50% { box-shadow: -15px -15px 0px 0px rgba(0,0,0,0.5), 15px 15px 0px 0px rgba(0,0,0,0.5); }
            100% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
        }

        #role-matching-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.6em;
            text-shadow: 2px 2px 0px #FCD116;
            font-family: 'Impact', sans-serif; /* Aggressive font */
            line-height: 1.3;
        }

        .role-matching-grid {
            display: grid;
            grid-template-columns: repeat(2, 1fr); /* 2 columns to make it more spread out */
            gap: 25px; /* Large gap */
            margin-top: 30px;
            margin-bottom: 30px;
            border: 3px ridge #FCD116; /* Ridge border */
            padding: 20px;
            background-color: #FAFAF0; /* Very light yellow */
            box-shadow: inset 0 0 10px rgba(0, 103, 71, 0.2);
            transform: skewY(1deg); /* Slight skew to the grid itself */
        }

        .person-card {
            border: 2px dashed #006747; /* Dashed green border */
            padding: 15px;
            background-color: #FFFFFF;
            box-shadow: 5px 5px 8px rgba(0, 0, 0, 0.15);
            text-align: center;
            transition: transform 0.3s ease-in-out;
            transform: rotate(calc(var(--rotation-deg) * 1deg)); /* Variable rotation for each card */
            position: relative;
        }

        .person-card:nth-child(odd) { --rotation-deg: -2; }
        .person-card:nth-child(even) { --rotation-deg: 2; }

        .person-card:hover {
            transform: scale(1.05) rotate(0deg); /* Straighten and zoom on hover */
            box-shadow: 0 0 15px #FCD116;
            border-color: #FCD116; /* Gold border on hover */
        }

        .person-card img {
            width: 100%;
            max-width: 150px; /* Consistent image size */
            height: 150px;
            object-fit: cover;
            border: 3px solid #FCD116; /* Gold border for image */
            border-radius: 50%; /* Make images circular */
            margin-bottom: 15px;
            filter: saturate(150%); /* Over-saturated images */
            animation: image-glow 2s infinite alternate;
        }

        @keyframes image-glow {
            0% { box-shadow: 0 0 5px #FCD116; }
            100% { box-shadow: 0 0 15px #FCD116, 0 0 20px #006747; }
        }

        .role-select {
            width: 80%;
            padding: 10px;
            margin-top: 10px;
            border: 2px solid #006747; /* Green border */
            border-radius: 5px;
            background-color: #E6FFE6; /* Light green background */
            font-size: 1em;
            font-family: 'Courier New', monospace; /* Annoying font for dropdown */
            color: #003300;
            cursor: pointer;
            appearance: none; /* Remove default arrow */
            background-image: url('data:image/svg+xml;charset=US-ASCII,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%22292.4%22%20height%3D%22292.4%22%3E%3Cpath%20fill%3D%22%23006747%22%20d%3D%22M287%2069.9a14.6%2014.6%200%200%200-20.7%200L146.2%20189.9%2026.1%2069.9a14.6%2014.6%200%200%200-20.7%2020.7l130.8%20130.9a14.6%2014.6%200%200%200%2020.7%200L287%2090.6a14.6%2014.6%200%200%200%200-20.7z%22%2F%3E%3C%2Fsvg%3E');
            background-repeat: no-repeat;
            background-position: right 10px top 50%;
            background-size: 16px;
            padding-right: 30px; /* Space for custom arrow */
        }

        .role-select:focus {
            outline: none;
            border-color: #FCD116;
            box-shadow: 0 0 0 3px rgba(252, 209, 22, 0.5);
        }

        #verify-role-btn {
            background-color: #006747; /* Green button */
            color: #FCD116; /* Gold text */
            padding: 20px 40px;
            border: 3px solid #FCD116; /* Gold border */
            border-radius: 10px;
            font-size: 1.3em;
            font-weight: bold;
            margin-top: 30px;
            width: auto;
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.7;
            transition: all 0.4s ease;
            transform: rotate(-5deg); /* Another annoying tilt */
            letter-spacing: 2px; /* Spaced out text */
        }

        #verify-role-btn:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text */
            transform: rotate(5deg) scale(1.03); /* Reverse tilt and scale */
            opacity: 1;
            box-shadow: 0 0 20px rgba(0, 103, 71, 0.7);
        }

        /* Validation feedback styles */
        .requirement-met {
            color: green !important;
            text-decoration: line-through;
            opacity: 0.7;
        }

        .requirement-not-met {
            color: red !important;
            font-weight: bold;
            animation: shake 0.5s;
        }

        @keyframes shake {
            0% { transform: translateX(0); }
            25% { transform: translateX(-5px); }
            50% { transform: translateX(5px); }
            75% { transform: translateX(-5px); }
            100% { transform: translateX(0); }
        }

    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form id="login-form" action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul id="password-requirements-list">
                    <li id="req-digit">At least one digit must be included.</li>
                    <li id="req-lowercase">At least one lowercase character is required.</li>
                    <li id="req-special">At least one special character (!@#$%^&*) is mandatory.</li>
                    <li id="req-uppercase">At least one uppercase character is required.</li>
                    <li id="req-minlength">Minimum length of 12 characters is enforced.</li>
                    <li id="req-dictionary">Must not contain common dictionary words.</li>
                    <li id="req-username">Must not contain your username.</li>
                    <li id="req-sequential">No sequential characters (e.g., 'abc', '123').</li>
                    <li id="req-history">Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <div id="captcha-challenge-container">
                <h3>Prove you are not a robot (or a very bored USF student) by selecting all images containing a single-celled organism riding a unicycle:</h3>
                <div class="captcha-grid">
                    <div class="captcha-item">
                        <input type="checkbox" id="img1" name="captcha-img" value="img1">
                        <img src="https://picsum.photos/id/60/150/150" alt="Abstract Image 1">
                        <label for="img1" style="display:none;">Select Image 1</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img2" name="captcha-img" value="img2">
                        <img src="https://picsum.photos/id/61/150/150" alt="Abstract Image 2">
                        <label for="img2" style="display:none;">Select Image 2</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img3" name="captcha-img" value="img3">
                        <img src="https://picsum.photos/id/62/150/150" alt="Abstract Image 3">
                        <label for="img3" style="display:none;">Select Image 3</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img4" name="captcha-img" value="img4">
                        <img src="https://picsum.photos/id/63/150/150" alt="Abstract Image 4">
                        <label for="img4" style="display:none;">Select Image 4</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img5" name="captcha-img" value="img5">
                        <img src="https://picsum.photos/id/64/150/150" alt="Abstract Image 5">
                        <label for="img5" style="display:none;">Select Image 5</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img6" name="captcha-img" value="img6">
                        <img src="https://picsum.photos/id/65/150/150" alt="Abstract Image 6">
                        <label for="img6" style="display:none;">Select Image 6</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img7" name="captcha-img" value="img7">
                        <img src="https://picsum.photos/id/66/150/150" alt="Abstract Image 7">
                        <label for="img7" style="display:none;">Select Image 7</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img8" name="captcha-img" value="img8">
                        <img src="https://picsum.photos/id/67/150/150" alt="Abstract Image 8">
                        <label for="img8" style="display:none;">Select Image 8</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img9" name="captcha-img" value="img9">
                        <img src="https://picsum.photos/id/68/150/150" alt="Abstract Image 9">
                        <label for="img9" style="display:none;">Select Image 9</label>
                    </div>
                </div>
                <button type="button" id="verify-captcha-btn">Verify Captcha (Good Luck!)</button>
            </div>

            <div id="role-matching-challenge-container">
                <h3>Match the individual to their highly classified USF role. Misclicking will result in academic probation!</h3>
                <div class="role-matching-grid">
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1005/150/150" alt="Person 1">
                        <select class="role-select" id="person1-role" name="person1-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1011/150/150" alt="Person 2">
                        <select class="role-select" id="person2-role" name="person2-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1025/150/150" alt="Person 3">
                        <select class="role-select" id="person3-role" name="person3-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1027/150/150" alt="Person 4">
                        <select class="role-select" id="person4-role" name="person4-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                </div>
                <button type="button" id="verify-role-btn">Verify Role Matches</button>
            </div>

            <button type="submit" id="final-login-btn">Proceed With Caution</button>
        </form>
    </div>

    <script>
        // Global flags for challenge completion
        let isCaptchaVerified = false;
        let isRoleMatchingVerified = false;

        // 1. Get references to all necessary HTML elements
        const loginForm = document.getElementById('login-form');
        const usernameInput = document.getElementById('username');
        const passwordInput = document.getElementById('password');
        const passwordRequirementsList = document.getElementById('password-requirements-list');
        const requirementItems = {
            digit: document.getElementById('req-digit'),
            lowercase: document.getElementById('req-lowercase'),
            special: document.getElementById('req-special'),
            uppercase: document.getElementById('req-uppercase'),
            minlength: document.getElementById('req-minlength'),
            dictionary: document.getElementById('req-dictionary'),
            username: document.getElementById('req-username'),
            sequential: document.getElementById('req-sequential'),
            history: document.getElementById('req-history')
        };

        const captchaGrid = document.querySelector('.captcha-grid');
        const captchaCheckboxes = document.querySelectorAll('.captcha-item input[type="checkbox"]');
        const verifyCaptchaBtn = document.getElementById('verify-captcha-btn');

        const roleMatchingGrid = document.querySelector('.role-matching-grid');
        const roleSelects = document.querySelectorAll('.role-select');
        const verifyRoleBtn = document.getElementById('verify-role-btn');

        const finalLoginBtn = document.getElementById('final-login-btn');

        // 2. Implement a JavaScript function for username and password validation
        function validatePassword() {
            const username = usernameInput.value;
            const password = passwordInput.value;
            let allRequirementsMet = true;

            // Helper to update requirement item style
            const updateRequirement = (item, condition) => {
                if (condition) {
                    item.classList.remove('requirement-not-met');
                    item.classList.add('requirement-met');
                } else {
                    item.classList.remove('requirement-met');
                    item.classList.add('requirement-not-met');
                    allRequirementsMet = false;
                }
            };

            // At least one digit
            updateRequirement(requirementItems.digit, /\d/.test(password));
            // At least one lowercase character
            updateRequirement(requirementItems.lowercase, /[a-z]/.test(password));
            // At least one special character
            updateRequirement(requirementItems.special, /[!@#$%^&*]/.test(password));
            // At least one uppercase character
            updateRequirement(requirementItems.uppercase, /[A-Z]/.test(password));
            // Minimum length of 12 characters
            updateRequirement(requirementItems.minlength, password.length >= 12);
            // Must not contain common dictionary words (simplified)
            const commonWords = ['password', '123456', 'qwerty', username]; // Add more words as needed
            let containsCommonWord = false;
            for (let word of commonWords) {
                if (password.toLowerCase().includes(word.toLowerCase())) {
                    containsCommonWord = true;
                    break;
                }
            }
            updateRequirement(requirementItems.dictionary, !containsCommonWord);
            // Must not contain your username
            updateRequirement(requirementItems.username, !password.toLowerCase().includes(username.toLowerCase()) || username === '');
            // No sequential characters (simplified for 'abc', '123')
            const isSequential = /(abc|bcd|cde|def|efg|fgh|ghi|hij|ijk|jkl|klm|lmn|mno|nop|opq|pqr|qrs|rst|stu|tuv|uvw|vwx|wxy|xyz)|(012|123|234|345|456|567|678|789)/.test(password);
            updateRequirement(requirementItems.sequential, !isSequential);
            // Password history check: Must be different from the last 10 passwords (client-side simulation)
            // For simplicity, we'll just check if it's 'oldpassword1' (dummy history)
            updateRequirement(requirementItems.history, password !== 'oldpassword1');

            return allRequirementsMet;
        }

        // Add event listener for password input to trigger validation
        passwordInput.addEventListener('input', validatePassword);

        // 3. Add an event listener to the captcha-grid to handle clicks on captcha images/checkboxes.
        captchaGrid.addEventListener('change', (event) => {
            if (event.target.type === 'checkbox') {
                const captchaItem = event.target.closest('.captcha-item');
                if (event.target.checked) {
                    captchaItem.classList.add('selected');
                } else {
                    captchaItem.classList.remove('selected');
                }
            }
        });

        // 4. Implement a JavaScript function for the image captcha verification.
        function verifyCaptcha() {
            const selectedImages = Array.from(captchaCheckboxes).filter(cb => cb.checked).map(cb => cb.id);
            // Predefined 'correct' images: img1, img5, img9
            const correctSelections = ['img1', 'img5', 'img9'];

            const isCorrect = correctSelections.every(imgId => selectedImages.includes(imgId)) &&
                              selectedImages.length === correctSelections.length;

            if (isCorrect) {
                isCaptchaVerified = true;
                verifyCaptchaBtn.textContent = 'Captcha VERIFIED! Finally!';
                verifyCaptchaBtn.style.backgroundColor = '#006747'; // Green
                verifyCaptchaBtn.style.color = '#FCD116'; // Gold text
                verifyCaptchaBtn.style.cursor = 'not-allowed';
                verifyCaptchaBtn.disabled = true;
                alert('Image Captcha successfully solved! (But was it really?)');
            } else {
                isCaptchaVerified = false;
                verifyCaptchaBtn.textContent = 'Captcha FAILED! Try again. Or don\'t.';
                verifyCaptchaBtn.style.backgroundColor = '#FF0000'; // Red
                verifyCaptchaBtn.style.color = 'white';
                verifyCaptchaBtn.style.cursor = 'pointer';
                verifyCaptchaBtn.disabled = false;
                alert('Incorrect Captcha selections. The unicycle-riding single-celled organisms are displeased.');
                // Optionally, clear selections or shuffle images for added annoyance
            }
            return isCaptchaVerified;
        }
        verifyCaptchaBtn.addEventListener('click', verifyCaptcha);

        // 5. Implement a JavaScript function for the person role matching verification.
        function verifyRoleMatching() {
            // Predefined correct role assignments: Person 1: Student, Person 2: Professor, Person 3: Staff, Person 4: Alumni
            const correctAssignments = {
                'person1-role': 'student',
                'person2-role': 'professor',
                'person3-role': 'staff',
                'person4-role': 'alumni'
            };

            let allRolesCorrect = true;
            roleSelects.forEach(select => {
                if (select.value !== correctAssignments[select.id]) {
                    allRolesCorrect = false;
                    // Annoying visual feedback for incorrect selections
                    select.style.borderColor = 'red';
                    select.style.boxShadow = '0 0 10px red';
                } else {
                    select.style.borderColor = '#006747';
                    select.style.boxShadow = '0 0 0 3px rgba(0, 103, 71, 0.5)';
                }
            });

            if (allRolesCorrect) {
                isRoleMatchingVerified = true;
                verifyRoleBtn.textContent = 'Roles MATCHED! Amazing!';
                verifyRoleBtn.style.backgroundColor = '#006747'; // Green
                verifyRoleBtn.style.color = '#FCD116'; // Gold
                verifyRoleBtn.style.cursor = 'not-allowed';
                verifyRoleBtn.disabled = true;
                alert('Role Matching Challenge Passed! Your intuition is unnerving.');
            } else {
                isRoleMatchingVerified = false;
                verifyRoleBtn.textContent = 'Role Mismatch Detected! Re-evaluate careers.';
                verifyRoleBtn.style.backgroundColor = '#FF0000'; // Red
                verifyRoleBtn.style.color = 'white';
                verifyRoleBtn.style.cursor = 'pointer';
                verifyRoleBtn.disabled = false;
                alert('Some roles are incorrect. The HR department has been notified.');
            }
            return isRoleMatchingVerified;
        }
        verifyRoleBtn.addEventListener('click', verifyRoleMatching);

        // 6. Add an event listener to the main login form's submit button.
        loginForm.addEventListener('submit', (event) => {
            event.preventDefault(); // Prevent default form submission

            // Validate all conditions
            const passwordValid = validatePassword();

            if (passwordValid && isCaptchaVerified && isRoleMatchingVerified) {
                alert('Congratulations! You\'ve navigated our impossible login. Just kidding, no actual login functionality here, this is a demo! Feel free to refresh.');
            } else {
                let errorMessage = 'Login Failed. The system requires perfection!\n\n';
                if (!passwordValid) {
                    errorMessage += '- Password does not meet all requirements.\n';
                }
                if (!isCaptchaVerified) {
                    errorMessage += '- Image Captcha not verified or incorrect.\n';
                }
                if (!isRoleMatchingVerified) {
                    errorMessage += '- Person Role Matching not verified or incorrect.\n';
                }
                alert(errorMessage + '\nDo not give up now!');
            }
        });

        // Initial password validation on load (in case there's pre-filled data)
        validatePassword();
    </script>
</body>
</html>
'''

from IPython.display import HTML
display(HTML(html_content))

print("HTML content with integrated JavaScript login logic, validation, and interactivity displayed.")
# Out:
# <>:651: SyntaxWarning: invalid escape sequence '\d'
# <>:651: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3771898524.py:651: SyntaxWarning: invalid escape sequence '\d'
#   updateRequirement(requirementItems.digit, /\d/.test(password));
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
# ...

# %% [markdown]
# **Reasoning**:
# The previous code generated a `SyntaxWarning` due to an unescaped backslash in a JavaScript regular expression within a Python string literal. I need to escape the backslash (`\d`) in the `updateRequirement(requirementItems.digit, /\d/.test(password));` line of the JavaScript code to ensure proper interpretation by Python.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

        /* Styling for Captcha Challenge Container */
        #captcha-challenge-container {
            background-color: #e0f2f1; /* Light green background */
            border: 4px dotted #FCD116; /* Gold dotted border */
            padding: 25px;
            margin-top: 40px;
            margin-bottom: 40px;
            border-radius: 15px;
            box-shadow: -8px 8px 12px rgba(0, 0, 0, 0.2); /* Offset shadow */
            font-size: 1.1em;
            color: #004d40; /* Darker green text */
            text-align: center;
            position: relative; /* For overlapping */
            left: -10px; /* Slightly off-center */
            transform: rotate(-3deg); /* Annoying tilt */
            z-index: 4; /* Higher z-index to overlap */
            animation: wiggle 0.5s infinite alternate; /* Subtle wiggling */
        }

        @keyframes wiggle {
            0% { transform: rotate(-3deg); }
            100% { transform: rotate(3deg); }
        }

        #captcha-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.4em;
            text-shadow: 1px 1px 0px #FCD116;
        }

        .captcha-grid {
            display: grid;
            grid-template-columns: repeat(3, 1fr); /* 3 columns */
            gap: 15px; /* Spacing between images */
            margin-top: 20px;
            margin-bottom: 20px;
            border: 2px dashed #006747; /* Green dashed border for the grid */
            padding: 10px;
            background-color: #fafafa;
        }

        .captcha-item {
            position: relative;
            border: 3px solid #ccc; /* Default border */
            cursor: pointer;
            overflow: hidden;
            transform: scale(0.98); /* Slightly smaller initially */
            transition: transform 0.2s ease-in-out, border-color 0.2s ease-in-out, box-shadow 0.2s ease-in-out;
        }

        .captcha-item:nth-child(even) { transform: rotate(1deg); } /* Annoying subtle rotation */
        .captcha-item:nth-child(odd) { transform: rotate(-1deg); }

        .captcha-item img {
            width: 100%;
            height: 120px; /* Fixed height for visual inconsistency */
            object-fit: cover;
            display: block;
            filter: grayscale(20%); /* Slightly desaturated */
        }

        .captcha-item input[type="checkbox"] {
            position: absolute;
            top: 5px;
            left: 5px;
            z-index: 10; /* Ensure checkbox is clickable */
            width: 25px;
            height: 25px;
            transform: scale(1.2); /* Larger checkbox */
            accent-color: #006747; /* Green checkbox */
            box-shadow: 0 0 0 3px #FCD116; /* Gold shadow on checkbox */
        }

        .captcha-item.selected {
            border-color: #006747; /* Green border when selected */
            box-shadow: 0 0 10px rgba(0, 103, 71, 0.5); /* Green glow */
            transform: scale(1.05) rotate(0deg) !important; /* Zoom and straighten on selection */
        }

        #verify-captcha-btn {
            background-color: #FCD116; /* Gold button */
            color: #006747; /* Green text */
            padding: 15px 30px;
            border: 2px solid #006747;
            border-radius: 5px;
            font-size: 1.1em;
            font-weight: bold;
            margin-top: 25px;
            width: auto; /* Not full width */
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.8;
            transition: all 0.3s ease;
            transform: skewX(-5deg); /* Annoying skew */
            position: relative;
        }

        #verify-captcha-btn:hover {
            background-color: #006747; /* Green on hover */
            color: #FCD116; /* Gold text */
            transform: skewX(5deg) scale(1.02); /* Reverse skew and slight scale */
            opacity: 1;
        }

        /* Styling for Role Matching Container */
        #role-matching-challenge-container {
            background-color: #F0F8FF; /* AliceBlue background for contrast */
            border: 6px double #006747; /* Double green border */
            padding: 30px;
            margin-top: 50px;
            margin-bottom: 50px;
            border-radius: 20px;
            box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; /* Gold and Red offset shadows */
            font-size: 1.2em;
            color: #333333;
            text-align: center;
            position: relative; /* For overlapping and positioning */
            left: 15px; /* Intentionally offset */
            transform: rotate(4deg); /* Significant tilt */
            z-index: 5; /* Highest z-index to be most prominent */
            animation: pulse-shadow 3s infinite alternate;
        }

        @keyframes pulse-shadow {
            0% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
            50% { box-shadow: -15px -15px 0px 0px rgba(0,0,0,0.5), 15px 15px 0px 0px rgba(0,0,0,0.5); }
            100% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
        }

        #role-matching-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.6em;
            text-shadow: 2px 2px 0px #FCD116;
            font-family: 'Impact', sans-serif; /* Aggressive font */
            line-height: 1.3;
        }

        .role-matching-grid {
            display: grid;
            grid-template-columns: repeat(2, 1fr); /* 2 columns to make it more spread out */
            gap: 25px; /* Large gap */
            margin-top: 30px;
            margin-bottom: 30px;
            border: 3px ridge #FCD116; /* Ridge border */
            padding: 20px;
            background-color: #FAFAF0; /* Very light yellow */
            box-shadow: inset 0 0 10px rgba(0, 103, 71, 0.2);
            transform: skewY(1deg); /* Slight skew to the grid itself */
        }

        .person-card {
            border: 2px dashed #006747; /* Dashed green border */
            padding: 15px;
            background-color: #FFFFFF;
            box-shadow: 5px 5px 8px rgba(0, 0, 0, 0.15);
            text-align: center;
            transition: transform 0.3s ease-in-out;
            transform: rotate(calc(var(--rotation-deg) * 1deg)); /* Variable rotation for each card */
            position: relative;
        }

        .person-card:nth-child(odd) { --rotation-deg: -2; }
        .person-card:nth-child(even) { --rotation-deg: 2; }

        .person-card:hover {
            transform: scale(1.05) rotate(0deg); /* Straighten and zoom on hover */
            box-shadow: 0 0 15px #FCD116;
            border-color: #FCD116; /* Gold border on hover */
        }

        .person-card img {
            width: 100%;
            max-width: 150px; /* Consistent image size */
            height: 150px;
            object-fit: cover;
            border: 3px solid #FCD116; /* Gold border for image */
            border-radius: 50%; /* Make images circular */
            margin-bottom: 15px;
            filter: saturate(150%); /* Over-saturated images */
            animation: image-glow 2s infinite alternate;
        }

        @keyframes image-glow {
            0% { box-shadow: 0 0 5px #FCD116; }
            100% { box-shadow: 0 0 15px #FCD116, 0 0 20px #006747; }
        }

        .role-select {
            width: 80%;
            padding: 10px;
            margin-top: 10px;
            border: 2px solid #006747; /* Green border */
            border-radius: 5px;
            background-color: #E6FFE6; /* Light green background */
            font-size: 1em;
            font-family: 'Courier New', monospace; /* Annoying font for dropdown */
            color: #003300;
            cursor: pointer;
            appearance: none; /* Remove default arrow */
            background-image: url('data:image/svg+xml;charset=US-ASCII,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%22292.4%22%20height%3D%22292.4%22%3E%3Cpath%20fill%3D%22%23006747%22%20d%3D%22M287%2069.9a14.6%2014.6%200%200%200-20.7%200L146.2%20189.9%2026.1%2069.9a14.6%2014.6%200%200%200-20.7%2020.7l130.8%20130.9a14.6%2014.6%200%200%200%2020.7%200L287%2090.6a14.6%2014.6%200%200%200%200-20.7z%22%2F%3E%3C%2Fsvg%3E');
            background-repeat: no-repeat;
            background-position: right 10px top 50%;
            background-size: 16px;
            padding-right: 30px; /* Space for custom arrow */
        }

        .role-select:focus {
            outline: none;
            border-color: #FCD116;
            box-shadow: 0 0 0 3px rgba(252, 209, 22, 0.5);
        }

        #verify-role-btn {
            background-color: #006747; /* Green button */
            color: #FCD116; /* Gold text */
            padding: 20px 40px;
            border: 3px solid #FCD116; /* Gold border */
            border-radius: 10px;
            font-size: 1.3em;
            font-weight: bold;
            margin-top: 30px;
            width: auto;
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.7;
            transition: all 0.4s ease;
            transform: rotate(-5deg); /* Another annoying tilt */
            letter-spacing: 2px; /* Spaced out text */
        }

        #verify-role-btn:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text */
            transform: rotate(5deg) scale(1.03); /* Reverse tilt and scale */
            opacity: 1;
            box-shadow: 0 0 20px rgba(0, 103, 71, 0.7);
        }

        /* Validation feedback styles */
        .requirement-met {
            color: green !important;
            text-decoration: line-through;
            opacity: 0.7;
        }

        .requirement-not-met {
            color: red !important;
            font-weight: bold;
            animation: shake 0.5s;
        }

        @keyframes shake {
            0% { transform: translateX(0); }
            25% { transform: translateX(-5px); }
            50% { transform: translateX(5px); }
            75% { transform: translateX(-5px); }
            100% { transform: translateX(0); }
        }

    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form id="login-form" action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul id="password-requirements-list">
                    <li id="req-digit">At least one digit must be included.</li>
                    <li id="req-lowercase">At least one lowercase character is required.</li>
                    <li id="req-special">At least one special character (!@#$%^&*) is mandatory.</li>
                    <li id="req-uppercase">At least one uppercase character is required.</li>
                    <li id="req-minlength">Minimum length of 12 characters is enforced.</li>
                    <li id="req-dictionary">Must not contain common dictionary words.</li>
                    <li id="req-username">Must not contain your username.</li>
                    <li id="req-sequential">No sequential characters (e.g., 'abc', '123').</li>
                    <li id="req-history">Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <div id="captcha-challenge-container">
                <h3>Prove you are not a robot (or a very bored USF student) by selecting all images containing a single-celled organism riding a unicycle:</h3>
                <div class="captcha-grid">
                    <div class="captcha-item">
                        <input type="checkbox" id="img1" name="captcha-img" value="img1">
                        <img src="https://picsum.photos/id/60/150/150" alt="Abstract Image 1">
                        <label for="img1" style="display:none;">Select Image 1</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img2" name="captcha-img" value="img2">
                        <img src="https://picsum.photos/id/61/150/150" alt="Abstract Image 2">
                        <label for="img2" style="display:none;">Select Image 2</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img3" name="captcha-img" value="img3">
                        <img src="https://picsum.photos/id/62/150/150" alt="Abstract Image 3">
                        <label for="img3" style="display:none;">Select Image 3</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img4" name="captcha-img" value="img4">
                        <img src="https://picsum.photos/id/63/150/150" alt="Abstract Image 4">
                        <label for="img4" style="display:none;">Select Image 4</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img5" name="captcha-img" value="img5">
                        <img src="https://picsum.photos/id/64/150/150" alt="Abstract Image 5">
                        <label for="img5" style="display:none;">Select Image 5</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img6" name="captcha-img" value="img6">
                        <img src="https://picsum.photos/id/65/150/150" alt="Abstract Image 6">
                        <label for="img6" style="display:none;">Select Image 6</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img7" name="captcha-img" value="img7">
                        <img src="https://picsum.photos/id/66/150/150" alt="Abstract Image 7">
                        <label for="img7" style="display:none;">Select Image 7</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img8" name="captcha-img" value="img8">
                        <img src="https://picsum.photos/id/67/150/150" alt="Abstract Image 8">
                        <label for="img8" style="display:none;">Select Image 8</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img9" name="captcha-img" value="img9">
                        <img src="https://picsum.photos/id/68/150/150" alt="Abstract Image 9">
                        <label for="img9" style="display:none;">Select Image 9</label>
                    </div>
                </div>
                <button type="button" id="verify-captcha-btn">Verify Captcha (Good Luck!)</button>
            </div>

            <div id="role-matching-challenge-container">
                <h3>Match the individual to their highly classified USF role. Misclicking will result in academic probation!</h3>
                <div class="role-matching-grid">
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1005/150/150" alt="Person 1">
                        <select class="role-select" id="person1-role" name="person1-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1011/150/150" alt="Person 2">
                        <select class="role-select" id="person2-role" name="person2-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1025/150/150" alt="Person 3">
                        <select class="role-select" id="person3-role" name="person3-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1027/150/150" alt="Person 4">
                        <select class="role-select" id="person4-role" name="person4-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                </div>
                <button type="button" id="verify-role-btn">Verify Role Matches</button>
            </div>

            <button type="submit" id="final-login-btn">Proceed With Caution</button>
        </form>
    </div>

    <script>
        // Global flags for challenge completion
        let isCaptchaVerified = false;
        let isRoleMatchingVerified = false;

        // 1. Get references to all necessary HTML elements
        const loginForm = document.getElementById('login-form');
        const usernameInput = document.getElementById('username');
        const passwordInput = document.getElementById('password');
        const passwordRequirementsList = document.getElementById('password-requirements-list');
        const requirementItems = {
            digit: document.getElementById('req-digit'),
            lowercase: document.getElementById('req-lowercase'),
            special: document.getElementById('req-special'),
            uppercase: document.getElementById('req-uppercase'),
            minlength: document.getElementById('req-minlength'),
            dictionary: document.getElementById('req-dictionary'),
            username: document.getElementById('req-username'),
            sequential: document.getElementById('req-sequential'),
            history: document.getElementById('req-history')
        };

        const captchaGrid = document.querySelector('.captcha-grid');
        const captchaCheckboxes = document.querySelectorAll('.captcha-item input[type="checkbox"]');
        const verifyCaptchaBtn = document.getElementById('verify-captcha-btn');

        const roleMatchingGrid = document.querySelector('.role-matching-grid');
        const roleSelects = document.querySelectorAll('.role-select');
        const verifyRoleBtn = document.getElementById('verify-role-btn');

        const finalLoginBtn = document.getElementById('final-login-btn');

        // 2. Implement a JavaScript function for username and password validation
        function validatePassword() {
            const username = usernameInput.value;
            const password = passwordInput.value;
            let allRequirementsMet = true;

            // Helper to update requirement item style
            const updateRequirement = (item, condition) => {
                if (condition) {
                    item.classList.remove('requirement-not-met');
                    item.classList.add('requirement-met');
                } else {
                    item.classList.remove('requirement-met');
                    item.classList.add('requirement-not-met');
                    allRequirementsMet = false;
                }
            };

            // At least one digit
            updateRequirement(requirementItems.digit, /\d/.test(password));
            // At least one lowercase character
            updateRequirement(requirementItems.lowercase, /[a-z]/.test(password));
            // At least one special character
            updateRequirement(requirementItems.special, /[!@#$%^&*]/.test(password));
            // At least one uppercase character
            updateRequirement(requirementItems.uppercase, /[A-Z]/.test(password));
            // Minimum length of 12 characters
            updateRequirement(requirementItems.minlength, password.length >= 12);
            // Must not contain common dictionary words (simplified)
            const commonWords = ['password', '123456', 'qwerty', username]; // Add more words as needed
            let containsCommonWord = false;
            for (let word of commonWords) {
                if (password.toLowerCase().includes(word.toLowerCase())) {
                    containsCommonWord = true;
                    break;
                }
            }
            updateRequirement(requirementItems.dictionary, !containsCommonWord);
            // Must not contain your username
            updateRequirement(requirementItems.username, !password.toLowerCase().includes(username.toLowerCase()) || username === '');
            // No sequential characters (simplified for 'abc', '123')
            const isSequential = /(abc|bcd|cde|def|efg|fgh|ghi|hij|ijk|jkl|klm|lmn|mno|nop|opq|pqr|qrs|rst|stu|tuv|uvw|vwx|wxy|xyz)|(012|123|234|345|456|567|678|789)/.test(password);
            updateRequirement(requirementItems.sequential, !isSequential);
            // Password history check: Must be different from the last 10 passwords (client-side simulation)
            // For simplicity, we'll just check if it's 'oldpassword1' (dummy history)
            updateRequirement(requirementItems.history, password !== 'oldpassword1');

            return allRequirementsMet;
        }

        // Add event listener for password input to trigger validation
        passwordInput.addEventListener('input', validatePassword);

        // 3. Add an event listener to the captcha-grid to handle clicks on captcha images/checkboxes.
        captchaGrid.addEventListener('change', (event) => {
            if (event.target.type === 'checkbox') {
                const captchaItem = event.target.closest('.captcha-item');
                if (event.target.checked) {
                    captchaItem.classList.add('selected');
                } else {
                    captchaItem.classList.remove('selected');
                }
            }
        });

        // 4. Implement a JavaScript function for the image captcha verification.
        function verifyCaptcha() {
            const selectedImages = Array.from(captchaCheckboxes).filter(cb => cb.checked).map(cb => cb.id);
            // Predefined 'correct' images: img1, img5, img9
            const correctSelections = ['img1', 'img5', 'img9'];

            const isCorrect = correctSelections.every(imgId => selectedImages.includes(imgId)) &&
                              selectedImages.length === correctSelections.length;

            if (isCorrect) {
                isCaptchaVerified = true;
                verifyCaptchaBtn.textContent = 'Captcha VERIFIED! Finally!';
                verifyCaptchaBtn.style.backgroundColor = '#006747'; // Green
                verifyCaptchaBtn.style.color = '#FCD116'; // Gold text
                verifyCaptchaBtn.style.cursor = 'not-allowed';
                verifyCaptchaBtn.disabled = true;
                alert('Image Captcha successfully solved! (But was it really?)');
            } else {
                isCaptchaVerified = false;
                verifyCaptchaBtn.textContent = 'Captcha FAILED! Try again. Or don\'t.';
                verifyCaptchaBtn.style.backgroundColor = '#FF0000'; // Red
                verifyCaptchaBtn.style.color = 'white';
                verifyCaptchaBtn.style.cursor = 'pointer';
                verifyCaptchaBtn.disabled = false;
                alert('Incorrect Captcha selections. The unicycle-riding single-celled organisms are displeased.');
                // Optionally, clear selections or shuffle images for added annoyance
            }
            return isCaptchaVerified;
        }
        verifyCaptchaBtn.addEventListener('click', verifyCaptcha);

        // 5. Implement a JavaScript function for the person role matching verification.
        function verifyRoleMatching() {
            // Predefined correct role assignments: Person 1: Student, Person 2: Professor, Person 3: Staff, Person 4: Alumni
            const correctAssignments = {
                'person1-role': 'student',
                'person2-role': 'professor',
                'person3-role': 'staff',
                'person4-role': 'alumni'
            };

            let allRolesCorrect = true;
            roleSelects.forEach(select => {
                if (select.value !== correctAssignments[select.id]) {
                    allRolesCorrect = false;
                    // Annoying visual feedback for incorrect selections
                    select.style.borderColor = 'red';
                    select.style.boxShadow = '0 0 10px red';
                } else {
                    select.style.borderColor = '#006747';
                    select.style.boxShadow = '0 0 0 3px rgba(0, 103, 71, 0.5)';
                }
            });

            if (allRolesCorrect) {
                isRoleMatchingVerified = true;
                verifyRoleBtn.textContent = 'Roles MATCHED! Amazing!';
                verifyRoleBtn.style.backgroundColor = '#006747'; // Green
                verifyRoleBtn.style.color = '#FCD116'; // Gold
                verifyRoleBtn.style.cursor = 'not-allowed';
                verifyRoleBtn.disabled = true;
                alert('Role Matching Challenge Passed! Your intuition is unnerving.');
            } else {
                isRoleMatchingVerified = false;
                verifyRoleBtn.textContent = 'Role Mismatch Detected! Re-evaluate careers.';
                verifyRoleBtn.style.backgroundColor = '#FF0000'; // Red
                verifyRoleBtn.style.color = 'white';
                verifyRoleBtn.style.cursor = 'pointer';
                verifyRoleBtn.disabled = false;
                alert('Some roles are incorrect. The HR department has been notified.');
            }
            return isRoleMatchingVerified;
        }
        verifyRoleBtn.addEventListener('click', verifyRoleMatching);

        // 6. Add an event listener to the main login form\'s submit button.
        loginForm.addEventListener('submit', (event) => {
            event.preventDefault(); // Prevent default form submission

            // Validate all conditions
            const passwordValid = validatePassword();

            if (passwordValid && isCaptchaVerified && isRoleMatchingVerified) {
                alert('Congratulations! You\'ve navigated our impossible login. Just kidding, no actual login functionality here, this is a demo! Feel free to refresh.');
            } else {
                let errorMessage = 'Login Failed. The system requires perfection!\n\n';
                if (!passwordValid) {
                    errorMessage += '- Password does not meet all requirements.\n';
                }
                if (!isCaptchaVerified) {
                    errorMessage += '- Image Captcha not verified or incorrect.\n';
                }
                if (!isRoleMatchingVerified) {
                    errorMessage += '- Person Role Matching not verified or incorrect.\n';
                }
                alert(errorMessage + '\nDo not give up now!');
            }
        });

        // Initial password validation on load (in case there\'s pre-filled data)
        validatePassword();
    </script>
</body>
</html>
'''

from IPython.display import HTML
display(HTML(html_content))

print("HTML content with integrated JavaScript login logic, validation, and interactivity displayed.")
# Out:
# <>:651: SyntaxWarning: invalid escape sequence '\d'
# <>:651: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1072660737.py:651: SyntaxWarning: invalid escape sequence '\d'
#   updateRequirement(requirementItems.digit, /\d/.test(password));
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
# ...

# %% [markdown]
# **Reasoning**:
# The previous code generated a `SyntaxWarning` because `\d` was not properly escaped within the Python string literal, leading Python to interpret `\d` as an invalid escape sequence. I will fix this by changing `\d` to `\\d` in the JavaScript regular expression within the Python string, ensuring it is passed correctly to the browser's JavaScript engine and resolves the warning.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

        /* Styling for Captcha Challenge Container */
        #captcha-challenge-container {
            background-color: #e0f2f1; /* Light green background */
            border: 4px dotted #FCD116; /* Gold dotted border */
            padding: 25px;
            margin-top: 40px;
            margin-bottom: 40px;
            border-radius: 15px;
            box-shadow: -8px 8px 12px rgba(0, 0, 0, 0.2); /* Offset shadow */
            font-size: 1.1em;
            color: #004d40; /* Darker green text */
            text-align: center;
            position: relative; /* For overlapping */
            left: -10px; /* Slightly off-center */
            transform: rotate(-3deg); /* Annoying tilt */
            z-index: 4; /* Higher z-index to overlap */
            animation: wiggle 0.5s infinite alternate; /* Subtle wiggling */
        }

        @keyframes wiggle {
            0% { transform: rotate(-3deg); }
            100% { transform: rotate(3deg); }
        }

        #captcha-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.4em;
            text-shadow: 1px 1px 0px #FCD116;
        }

        .captcha-grid {
            display: grid;
            grid-template-columns: repeat(3, 1fr); /* 3 columns */
            gap: 15px; /* Spacing between images */
            margin-top: 20px;
            margin-bottom: 20px;
            border: 2px dashed #006747; /* Green dashed border for the grid */
            padding: 10px;
            background-color: #fafafa;
        }

        .captcha-item {
            position: relative;
            border: 3px solid #ccc; /* Default border */
            cursor: pointer;
            overflow: hidden;
            transform: scale(0.98); /* Slightly smaller initially */
            transition: transform 0.2s ease-in-out, border-color 0.2s ease-in-out, box-shadow 0.2s ease-in-out;
        }

        .captcha-item:nth-child(even) { transform: rotate(1deg); } /* Annoying subtle rotation */
        .captcha-item:nth-child(odd) { transform: rotate(-1deg); }

        .captcha-item img {
            width: 100%;
            height: 120px; /* Fixed height for visual inconsistency */
            object-fit: cover;
            display: block;
            filter: grayscale(20%); /* Slightly desaturated */
        }

        .captcha-item input[type="checkbox"] {
            position: absolute;
            top: 5px;
            left: 5px;
            z-index: 10; /* Ensure checkbox is clickable */
            width: 25px;
            height: 25px;
            transform: scale(1.2); /* Larger checkbox */
            accent-color: #006747; /* Green checkbox */
            box-shadow: 0 0 0 3px #FCD116; /* Gold shadow on checkbox */
        }

        .captcha-item.selected {
            border-color: #006747; /* Green border when selected */
            box-shadow: 0 0 10px rgba(0, 103, 71, 0.5); /* Green glow */
            transform: scale(1.05) rotate(0deg) !important; /* Zoom and straighten on selection */
        }

        #verify-captcha-btn {
            background-color: #FCD116; /* Gold button */
            color: #006747; /* Green text */
            padding: 15px 30px;
            border: 2px solid #006747;
            border-radius: 5px;
            font-size: 1.1em;
            font-weight: bold;
            margin-top: 25px;
            width: auto; /* Not full width */
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.8;
            transition: all 0.3s ease;
            transform: skewX(-5deg); /* Annoying skew */
            position: relative;
        }

        #verify-captcha-btn:hover {
            background-color: #006747; /* Green on hover */
            color: #FCD116; /* Gold text */
            transform: skewX(5deg) scale(1.02); /* Reverse skew and slight scale */
            opacity: 1;
        }

        /* Styling for Role Matching Container */
        #role-matching-challenge-container {
            background-color: #F0F8FF; /* AliceBlue background for contrast */
            border: 6px double #006747; /* Double green border */
            padding: 30px;
            margin-top: 50px;
            margin-bottom: 50px;
            border-radius: 20px;
            box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; /* Gold and Red offset shadows */
            font-size: 1.2em;
            color: #333333;
            text-align: center;
            position: relative; /* For overlapping and positioning */
            left: 15px; /* Intentionally offset */
            transform: rotate(4deg); /* Significant tilt */
            z-index: 5; /* Highest z-index to be most prominent */
            animation: pulse-shadow 3s infinite alternate;
        }

        @keyframes pulse-shadow {
            0% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
            50% { box-shadow: -15px -15px 0px 0px rgba(0,0,0,0.5), 15px 15px 0px 0px rgba(0,0,0,0.5); }
            100% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
        }

        #role-matching-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.6em;
            text-shadow: 2px 2px 0px #FCD116;
            font-family: 'Impact', sans-serif; /* Aggressive font */
            line-height: 1.3;
        }

        .role-matching-grid {
            display: grid;
            grid-template-columns: repeat(2, 1fr); /* 2 columns to make it more spread out */
            gap: 25px; /* Large gap */
            margin-top: 30px;
            margin-bottom: 30px;
            border: 3px ridge #FCD116; /* Ridge border */
            padding: 20px;
            background-color: #FAFAF0; /* Very light yellow */
            box-shadow: inset 0 0 10px rgba(0, 103, 71, 0.2);
            transform: skewY(1deg); /* Slight skew to the grid itself */
        }

        .person-card {
            border: 2px dashed #006747; /* Dashed green border */
            padding: 15px;
            background-color: #FFFFFF;
            box-shadow: 5px 5px 8px rgba(0, 0, 0, 0.15);
            text-align: center;
            transition: transform 0.3s ease-in-out;
            transform: rotate(calc(var(--rotation-deg) * 1deg)); /* Variable rotation for each card */
            position: relative;
        }

        .person-card:nth-child(odd) { --rotation-deg: -2; }
        .person-card:nth-child(even) { --rotation-deg: 2; }

        .person-card:hover {
            transform: scale(1.05) rotate(0deg); /* Straighten and zoom on hover */
            box-shadow: 0 0 15px #FCD116;
            border-color: #FCD116; /* Gold border on hover */
        }

        .person-card img {
            width: 100%;
            max-width: 150px; /* Consistent image size */
            height: 150px;
            object-fit: cover;
            border: 3px solid #FCD116; /* Gold border for image */
            border-radius: 50%; /* Make images circular */
            margin-bottom: 15px;
            filter: saturate(150%); /* Over-saturated images */
            animation: image-glow 2s infinite alternate;
        }

        @keyframes image-glow {
            0% { box-shadow: 0 0 5px #FCD116; }
            100% { box-shadow: 0 0 15px #FCD116, 0 0 20px #006747; }
        }

        .role-select {
            width: 80%;
            padding: 10px;
            margin-top: 10px;
            border: 2px solid #006747; /* Green border */
            border-radius: 5px;
            background-color: #E6FFE6; /* Light green background */
            font-size: 1em;
            font-family: 'Courier New', monospace; /* Annoying font for dropdown */
            color: #003300;
            cursor: pointer;
            appearance: none; /* Remove default arrow */
            background-image: url('data:image/svg+xml;charset=US-ASCII,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%22292.4%22%20height%3D%22292.4%22%3E%3Cpath%20fill%3D%22%23006747%22%20d%3D%22M287%2069.9a14.6%2014.6%200%200%200-20.7%200L146.2%20189.9%2026.1%2069.9a14.6%2014.6%200%200%200-20.7%2020.7l130.8%20130.9a14.6%2014.6%200%200%200%2020.7%200L287%2090.6a14.6%2014.6%200%200%200%200-20.7z%22%2F%3E%3C%2Fsvg%3E');
            background-repeat: no-repeat;
            background-position: right 10px top 50%;
            background-size: 16px;
            padding-right: 30px; /* Space for custom arrow */
        }

        .role-select:focus {
            outline: none;
            border-color: #FCD116;
            box-shadow: 0 0 0 3px rgba(252, 209, 22, 0.5);
        }

        #verify-role-btn {
            background-color: #006747; /* Green button */
            color: #FCD116; /* Gold text */
            padding: 20px 40px;
            border: 3px solid #FCD116; /* Gold border */
            border-radius: 10px;
            font-size: 1.3em;
            font-weight: bold;
            margin-top: 30px;
            width: auto;
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.7;
            transition: all 0.4s ease;
            transform: rotate(-5deg); /* Another annoying tilt */
            letter-spacing: 2px; /* Spaced out text */
        }

        #verify-role-btn:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text */
            transform: rotate(5deg) scale(1.03); /* Reverse tilt and scale */
            opacity: 1;
            box-shadow: 0 0 20px rgba(0, 103, 71, 0.7);
        }

        /* Validation feedback styles */
        .requirement-met {
            color: green !important;
            text-decoration: line-through;
            opacity: 0.7;
        }

        .requirement-not-met {
            color: red !important;
            font-weight: bold;
            animation: shake 0.5s;
        }

        @keyframes shake {
            0% { transform: translateX(0); }
            25% { transform: translateX(-5px); }
            50% { transform: translateX(5px); }
            75% { transform: translateX(-5px); }
            100% { transform: translateX(0); }
        }

    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form id="login-form" action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul id="password-requirements-list">
                    <li id="req-digit">At least one digit must be included.</li>
                    <li id="req-lowercase">At least one lowercase character is required.</li>
                    <li id="req-special">At least one special character (!@#$%^&*) is mandatory.</li>
                    <li id="req-uppercase">At least one uppercase character is required.</li>
                    <li id="req-minlength">Minimum length of 12 characters is enforced.</li>
                    <li id="req-dictionary">Must not contain common dictionary words.</li>
                    <li id="req-username">Must not contain your username.</li>
                    <li id="req-sequential">No sequential characters (e.g., 'abc', '123').</li>
                    <li id="req-history">Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <div id="captcha-challenge-container">
                <h3>Prove you are not a robot (or a very bored USF student) by selecting all images containing a single-celled organism riding a unicycle:</h3>
                <div class="captcha-grid">
                    <div class="captcha-item">
                        <input type="checkbox" id="img1" name="captcha-img" value="img1">
                        <img src="https://picsum.photos/id/60/150/150" alt="Abstract Image 1">
                        <label for="img1" style="display:none;">Select Image 1</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img2" name="captcha-img" value="img2">
                        <img src="https://picsum.photos/id/61/150/150" alt="Abstract Image 2">
                        <label for="img2" style="display:none;">Select Image 2</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img3" name="captcha-img" value="img3">
                        <img src="https://picsum.photos/id/62/150/150" alt="Abstract Image 3">
                        <label for="img3" style="display:none;">Select Image 3</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img4" name="captcha-img" value="img4">
                        <img src="https://picsum.photos/id/63/150/150" alt="Abstract Image 4">
                        <label for="img4" style="display:none;">Select Image 4</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img5" name="captcha-img" value="img5">
                        <img src="https://picsum.photos/id/64/150/150" alt="Abstract Image 5">
                        <label for="img5" style="display:none;">Select Image 5</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img6" name="captcha-img" value="img6">
                        <img src="https://picsum.photos/id/65/150/150" alt="Abstract Image 6">
                        <label for="img6" style="display:none;">Select Image 6</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img7" name="captcha-img" value="img7">
                        <img src="https://picsum.photos/id/66/150/150" alt="Abstract Image 7">
                        <label for="img7" style="display:none;">Select Image 7</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img8" name="captcha-img" value="img8">
                        <img src="https://picsum.photos/id/67/150/150" alt="Abstract Image 8">
                        <label for="img8" style="display:none;">Select Image 8</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img9" name="captcha-img" value="img9">
                        <img src="https://picsum.photos/id/68/150/150" alt="Abstract Image 9">
                        <label for="img9" style="display:none;">Select Image 9</label>
                    </div>
                </div>
                <button type="button" id="verify-captcha-btn">Verify Captcha (Good Luck!)</button>
            </div>

            <div id="role-matching-challenge-container">
                <h3>Match the individual to their highly classified USF role. Misclicking will result in academic probation!</h3>
                <div class="role-matching-grid">
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1005/150/150" alt="Person 1">
                        <select class="role-select" id="person1-role" name="person1-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1011/150/150" alt="Person 2">
                        <select class="role-select" id="person2-role" name="person2-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1025/150/150" alt="Person 3">
                        <select class="role-select" id="person3-role" name="person3-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1027/150/150" alt="Person 4">
                        <select class="role-select" id="person4-role" name="person4-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                </div>
                <button type="button" id="verify-role-btn">Verify Role Matches</button>
            </div>

            <button type="submit" id="final-login-btn">Proceed With Caution</button>
        </form>
    </div>

    <script>
        // Global flags for challenge completion
        let isCaptchaVerified = false;
        let isRoleMatchingVerified = false;

        // 1. Get references to all necessary HTML elements
        const loginForm = document.getElementById('login-form');
        const usernameInput = document.getElementById('username');
        const passwordInput = document.getElementById('password');
        const passwordRequirementsList = document.getElementById('password-requirements-list');
        const requirementItems = {
            digit: document.getElementById('req-digit'),
            lowercase: document.getElementById('req-lowercase'),
            special: document.getElementById('req-special'),
            uppercase: document.getElementById('req-uppercase'),
            minlength: document.getElementById('req-minlength'),
            dictionary: document.getElementById('req-dictionary'),
            username: document.getElementById('req-username'),
            sequential: document.getElementById('req-sequential'),
            history: document.getElementById('req-history')
        };

        const captchaGrid = document.querySelector('.captcha-grid');
        const captchaCheckboxes = document.querySelectorAll('.captcha-item input[type="checkbox"]');
        const verifyCaptchaBtn = document.getElementById('verify-captcha-btn');

        const roleMatchingGrid = document.querySelector('.role-matching-grid');
        const roleSelects = document.querySelectorAll('.role-select');
        const verifyRoleBtn = document.getElementById('verify-role-btn');

        const finalLoginBtn = document.getElementById('final-login-btn');

        // 2. Implement a JavaScript function for username and password validation
        function validatePassword() {
            const username = usernameInput.value;
            const password = passwordInput.value;
            let allRequirementsMet = true;

            // Helper to update requirement item style
            const updateRequirement = (item, condition) => {
                if (condition) {
                    item.classList.remove('requirement-not-met');
                    item.classList.add('requirement-met');
                } else {
                    item.classList.remove('requirement-met');
                    item.classList.add('requirement-not-met');
                    allRequirementsMet = false;
                }
            };

            // At least one digit
            updateRequirement(requirementItems.digit, /\d/.test(password));
            // At least one lowercase character
            updateRequirement(requirementItems.lowercase, /[a-z]/.test(password));
            // At least one special character
            updateRequirement(requirementItems.special, /[!@#$%^&*]/.test(password));
            // At least one uppercase character
            updateRequirement(requirementItems.uppercase, /[A-Z]/.test(password));
            // Minimum length of 12 characters
            updateRequirement(requirementItems.minlength, password.length >= 12);
            // Must not contain common dictionary words (simplified)
            const commonWords = ['password', '123456', 'qwerty', username]; // Add more words as needed
            let containsCommonWord = false;
            for (let word of commonWords) {
                if (password.toLowerCase().includes(word.toLowerCase())) {
                    containsCommonWord = true;
                    break;
                }
            }
            updateRequirement(requirementItems.dictionary, !containsCommonWord);
            // Must not contain your username
            updateRequirement(requirementItems.username, !password.toLowerCase().includes(username.toLowerCase()) || username === '');
            // No sequential characters (simplified for 'abc', '123')
            const isSequential = /(abc|bcd|cde|def|efg|fgh|ghi|hij|ijk|jkl|klm|lmn|mno|nop|opq|pqr|qrs|rst|stu|tuv|uvw|vwx|wxy|xyz)|(012|123|234|345|456|567|678|789)/.test(password);
            updateRequirement(requirementItems.sequential, !isSequential);
            // Password history check: Must be different from the last 10 passwords (client-side simulation)
            // For simplicity, we'll just check if it's 'oldpassword1' (dummy history)
            updateRequirement(requirementItems.history, password !== 'oldpassword1');

            return allRequirementsMet;
        }

        // Add event listener for password input to trigger validation
        passwordInput.addEventListener('input', validatePassword);

        // 3. Add an event listener to the captcha-grid to handle clicks on captcha images/checkboxes.
        captchaGrid.addEventListener('change', (event) => {
            if (event.target.type === 'checkbox') {
                const captchaItem = event.target.closest('.captcha-item');
                if (event.target.checked) {
                    captchaItem.classList.add('selected');
                } else {
                    captchaItem.classList.remove('selected');
                }
            }
        });

        // 4. Implement a JavaScript function for the image captcha verification.
        function verifyCaptcha() {
            const selectedImages = Array.from(captchaCheckboxes).filter(cb => cb.checked).map(cb => cb.id);
            // Predefined 'correct' images: img1, img5, img9
            const correctSelections = ['img1', 'img5', 'img9'];

            const isCorrect = correctSelections.every(imgId => selectedImages.includes(imgId)) &&
                              selectedImages.length === correctSelections.length;

            if (isCorrect) {
                isCaptchaVerified = true;
                verifyCaptchaBtn.textContent = 'Captcha VERIFIED! Finally!';
                verifyCaptchaBtn.style.backgroundColor = '#006747'; // Green
                verifyCaptchaBtn.style.color = '#FCD116'; // Gold text
                verifyCaptchaBtn.style.cursor = 'not-allowed';
                verifyCaptchaBtn.disabled = true;
                alert('Image Captcha successfully solved! (But was it really?)');
            } else {
                isCaptchaVerified = false;
                verifyCaptchaBtn.textContent = 'Captcha FAILED! Try again. Or don\'t.';
                verifyCaptchaBtn.style.backgroundColor = '#FF0000'; // Red
                verifyCaptchaBtn.style.color = 'white';
                verifyCaptchaBtn.style.cursor = 'pointer';
                verifyCaptchaBtn.disabled = false;
                alert('Incorrect Captcha selections. The unicycle-riding single-celled organisms are displeased.');
                // Optionally, clear selections or shuffle images for added annoyance
            }
            return isCaptchaVerified;
        }
        verifyCaptchaBtn.addEventListener('click', verifyCaptcha);

        // 5. Implement a JavaScript function for the person role matching verification.
        function verifyRoleMatching() {
            // Predefined correct role assignments: Person 1: Student, Person 2: Professor, Person 3: Staff, Person 4: Alumni
            const correctAssignments = {
                'person1-role': 'student',
                'person2-role': 'professor',
                'person3-role': 'staff',
                'person4-role': 'alumni'
            };

            let allRolesCorrect = true;
            roleSelects.forEach(select => {
                if (select.value !== correctAssignments[select.id]) {
                    allRolesCorrect = false;
                    // Annoying visual feedback for incorrect selections
                    select.style.borderColor = 'red';
                    select.style.boxShadow = '0 0 10px red';
                } else {
                    select.style.borderColor = '#006747';
                    select.style.boxShadow = '0 0 0 3px rgba(0, 103, 71, 0.5)';
                }
            });

            if (allRolesCorrect) {
                isRoleMatchingVerified = true;
                verifyRoleBtn.textContent = 'Roles MATCHED! Amazing!';
                verifyRoleBtn.style.backgroundColor = '#006747'; // Green
                verifyRoleBtn.style.color = '#FCD116'; // Gold
                verifyRoleBtn.style.cursor = 'not-allowed';
                verifyRoleBtn.disabled = true;
                alert('Role Matching Challenge Passed! Your intuition is unnerving.');
            } else {
                isRoleMatchingVerified = false;
                verifyRoleBtn.textContent = 'Role Mismatch Detected! Re-evaluate careers.';
                verifyRoleBtn.style.backgroundColor = '#FF0000'; // Red
                verifyRoleBtn.style.color = 'white';
                verifyRoleBtn.style.cursor = 'pointer';
                verifyRoleBtn.disabled = false;
                alert('Some roles are incorrect. The HR department has been notified.');
            }
            return isRoleMatchingVerified;
        }
        verifyRoleBtn.addEventListener('click', verifyRoleMatching);

        // 6. Add an event listener to the main login form\'s submit button.
        loginForm.addEventListener('submit', (event) => {
            event.preventDefault(); // Prevent default form submission

            // Validate all conditions
            const passwordValid = validatePassword();

            if (passwordValid && isCaptchaVerified && isRoleMatchingVerified) {
                alert('Congratulations! You\'ve navigated our impossible login. Just kidding, no actual login functionality here, this is a demo! Feel free to refresh.');
            } else {
                let errorMessage = 'Login Failed. The system requires perfection!\n\n';
                if (!passwordValid) {
                    errorMessage += '- Password does not meet all requirements.\n';
                }
                if (!isCaptchaVerified) {
                    errorMessage += '- Image Captcha not verified or incorrect.\n';
                }
                if (!isRoleMatchingVerified) {
                    errorMessage += '- Person Role Matching not verified or incorrect.\n';
                }
                alert(errorMessage + '\nDo not give up now!');
            }
        });

        // Initial password validation on load (in case there\'s pre-filled data)
        validatePassword();
    </script>
</body>
</html>
'''

from IPython.display import HTML
display(HTML(html_content))

print("HTML content with integrated JavaScript login logic, validation, and interactivity displayed.")
# Out:
# <>:651: SyntaxWarning: invalid escape sequence '\d'
# <>:651: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3923721351.py:651: SyntaxWarning: invalid escape sequence '\d'
#   updateRequirement(requirementItems.digit, /\d/.test(password));
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
# ...

# %% [markdown]
# **Reasoning**:
# The previous code generated a `SyntaxWarning` because `\d` was not properly escaped within the Python string literal, leading Python to interpret `\d` as an invalid escape sequence. I will fix this by changing `\d` to `\\d` in the JavaScript regular expression within the Python string, ensuring it is passed correctly to the browser's JavaScript engine and resolves the warning.

# %%
html_content = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Annoying USF Login</title>
    <style>
        body {
            font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
            background-color: #f8f8f8; /* Off-white background */
            color: #006747; /* USF Green as primary text color */
            margin: 0;
            padding: 20px;
            display: flex;
            justify-content: center;
            align-items: center;
            min-height: 100vh; /* Ensure full viewport height */
            overflow: hidden; /* To prevent scrollbar from minor rotations */
        }

        .login-container {
            background-color: #ffffff; /* White background for the container */
            border: 5px solid #FCD116; /* USF Gold border */
            border-radius: 0px; /* Sharp edges */
            padding: 40px 50px; /* Large padding */
            box-shadow: 10px 10px 0px 0px rgba(0, 103, 71, 0.3); /* Annoying offset shadow */
            width: 50%; /* Intentionally wide */
            max-width: 550px;
            min-width: 300px;
            margin: 0 auto; /* Center initially */
            position: relative; /* For slight misalignment */
            top: 5px;
            left: 5px;
            transform: rotate(-1deg); /* Slight, annoying tilt */
            z-index: 2; /* Ensure it's above the background pattern */
        }

        h1 {
            color: #006747; /* USF Green for heading */
            font-family: 'Georgia', serif; /* Inconsistent font from body */
            text-align: center;
            margin-bottom: 40px; /* Large margin */
            text-shadow: 2px 2px 0px #FCD116; /* Gold text shadow */
        }

        .form-group {
            margin-bottom: 30px; /* Ample spacing */
            overflow: hidden; /* Clear floats */
        }

        label {
            display: block;
            color: #006747; /* USF Green for labels */
            font-weight: bold;
            margin-bottom: 10px; /* Small margin */
            font-size: 1.1em; /* Slightly larger labels */
            float: left; /* Annoying floating label */
            width: 30%; /* Take up some space */
            line-height: 2.5em; /* Align with input */
        }

        input[type="text"],
        input[type="password"] {
            width: 65%; /* Annoyingly doesn't fill 100% */
            padding: 15px; /* Large padding */
            border: 2px solid #FCD116; /* Gold border */
            background-color: rgba(0, 103, 71, 0.05); /* Very light green background */
            box-sizing: border-box;
            font-size: 1em;
            transition: all 0.3s ease-in-out; /* For subtle animation */
            float: right; /* Annoying floating input */
        }

        input[type="text"]:focus,
        input[type="password"]:focus {
            outline: none;
            border-color: #006747; /* Green on focus */
            box-shadow: 0 0 0 5px #FCD116; /* Flashing gold shadow on focus */
            transform: scale(1.01); /* Subtle zoom on focus */
        }

        button[type="submit"] {
            background-color: #006747; /* USF Green button */
            color: white;
            padding: 18px 35px; /* Extra large padding */
            border: none;
            border-radius: 0px;
            cursor: pointer;
            font-size: 1.2em;
            font-weight: bold;
            width: 100%; /* Full width button */
            margin-top: 40px; /* Large top margin */
            transition: background-color 0.4s ease, transform 0.2s ease, box-shadow 0.2s ease;
            position: relative; /* For extra annoyance */
            z-index: 1;
        }

        button[type="submit"]:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text on hover */
            transform: scale(1.03) rotate(1deg); /* Slightly larger and tilted on hover */
            box-shadow: 0 0 15px rgba(252, 209, 22, 0.7); /* Stronger gold shadow */
        }

        /* Cumbersome layout elements */
        @media (max-width: 768px) {
            .login-container {
                width: 80%; /* Even wider on smaller screens */
                margin: 0 auto;
                transform: rotate(0deg); /* Remove tilt on small screens, different annoyance */
            }
            label, input[type="text"], input[type="password"] {
                float: none; /* Remove floats for vertical stacking */
                width: 100%;
                margin-bottom: 15px;
            }
            label {
                text-align: center; /* Center labels on small screens */
            }
        }

        @keyframes distracting-flash {
            0% { opacity: 1; }
            50% { opacity: 0.8; }
            100% { opacity: 1; }
        }
        body::before {
            content: '';
            position: absolute;
            top: -20px; left: -20px; right: -20px; bottom: -20px;
            background: repeating-linear-gradient(
                45deg,
                #FCD116,
                #FCD116 10px,
                transparent 10px,
                transparent 20px
            ); /* Distracting background pattern */
            opacity: 0.1;
            z-index: 0;
            animation: distracting-flash 5s infinite; /* Subtle, annoying flashing */
        }
        .login-container { z-index: 1; position: relative; }

        /* Styling for Login Requirements Container */
        #login-requirements-container {
            background-color: #FFFFAA; /* Light gold background */
            border: 3px solid #FF0000; /* Bright red, obnoxious border */
            padding: 15px;
            margin-top: 30px;
            margin-bottom: 30px;
            border-radius: 8px;
            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.4); /* Strong shadow */
            font-size: 1.2em; /* Large font size */
            font-weight: bold;
            color: #333333; /* Dark text for contrast */
            text-align: left; /* Requirements should be readable */
            position: relative; /* For absolute positioning of obstructive elements */
            z-index: 3; /* Make sure it's above other elements */
            transform: rotate(2deg); /* Slightly tilted */
            animation: pulsate-border 2s infinite alternate; /* Annoying border pulsation */
        }

        @keyframes pulsate-border {
            0% { border-color: #FF0000; }
            100% { border-color: #FFFF00; }
        }

        #login-requirements-container h3 {
            color: #006747;
            margin-top: 0;
            text-align: center;
            margin-bottom: 15px;
        }

        #login-requirements-container ul {
            list-style-type: none; /* Remove default bullet points */
            padding: 0;
            margin: 0;
        }

        #login-requirements-container li {
            padding: 5px 0;
            color: #333333; /* Darker text */
            text-indent: -15px; /* Obstructive indentation */
            margin-left: 20px;
            position: relative;
            font-family: 'Comic Sans MS', cursive, sans-serif; /* Annoying font */
        }

        #login-requirements-container li:before {
            content: '🚨 ';
            position: absolute;
            left: 0;
            color: #FCD116; /* Gold bullet point */
            font-weight: normal;
            font-size: 0.8em; /* Smaller bullet */
            animation: spin 1s infinite linear; /* Spinning bullet */
        }

        @keyframes spin {
            from { transform: rotate(0deg); }
            to { transform: rotate(360deg); }
        }

        /* Styling for Captcha Challenge Container */
        #captcha-challenge-container {
            background-color: #e0f2f1; /* Light green background */
            border: 4px dotted #FCD116; /* Gold dotted border */
            padding: 25px;
            margin-top: 40px;
            margin-bottom: 40px;
            border-radius: 15px;
            box-shadow: -8px 8px 12px rgba(0, 0, 0, 0.2); /* Offset shadow */
            font-size: 1.1em;
            color: #004d40; /* Darker green text */
            text-align: center;
            position: relative; /* For overlapping */
            left: -10px; /* Slightly off-center */
            transform: rotate(-3deg); /* Annoying tilt */
            z-index: 4; /* Higher z-index to overlap */
            animation: wiggle 0.5s infinite alternate; /* Subtle wiggling */
        }

        @keyframes wiggle {
            0% { transform: rotate(-3deg); }
            100% { transform: rotate(3deg); }
        }

        #captcha-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.4em;
            text-shadow: 1px 1px 0px #FCD116;
        }

        .captcha-grid {
            display: grid;
            grid-template-columns: repeat(3, 1fr); /* 3 columns */
            gap: 15px; /* Spacing between images */
            margin-top: 20px;
            margin-bottom: 20px;
            border: 2px dashed #006747; /* Green dashed border for the grid */
            padding: 10px;
            background-color: #fafafa;
        }

        .captcha-item {
            position: relative;
            border: 3px solid #ccc; /* Default border */
            cursor: pointer;
            overflow: hidden;
            transform: scale(0.98); /* Slightly smaller initially */
            transition: transform 0.2s ease-in-out, border-color 0.2s ease-in-out, box-shadow 0.2s ease-in-out;
        }

        .captcha-item:nth-child(even) { transform: rotate(1deg); } /* Annoying subtle rotation */
        .captcha-item:nth-child(odd) { transform: rotate(-1deg); }

        .captcha-item img {
            width: 100%;
            height: 120px; /* Fixed height for visual inconsistency */
            object-fit: cover;
            display: block;
            filter: grayscale(20%); /* Slightly desaturated */
        }

        .captcha-item input[type="checkbox"] {
            position: absolute;
            top: 5px;
            left: 5px;
            z-index: 10; /* Ensure checkbox is clickable */
            width: 25px;
            height: 25px;
            transform: scale(1.2); /* Larger checkbox */
            accent-color: #006747; /* Green checkbox */
            box-shadow: 0 0 0 3px #FCD116; /* Gold shadow on checkbox */
        }

        .captcha-item.selected {
            border-color: #006747; /* Green border when selected */
            box-shadow: 0 0 10px rgba(0, 103, 71, 0.5); /* Green glow */
            transform: scale(1.05) rotate(0deg) !important; /* Zoom and straighten on selection */
        }

        #verify-captcha-btn {
            background-color: #FCD116; /* Gold button */
            color: #006747; /* Green text */
            padding: 15px 30px;
            border: 2px solid #006747;
            border-radius: 5px;
            font-size: 1.1em;
            font-weight: bold;
            margin-top: 25px;
            width: auto; /* Not full width */
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.8;
            transition: all 0.3s ease;
            transform: skewX(-5deg); /* Annoying skew */
            position: relative;
        }

        #verify-captcha-btn:hover {
            background-color: #006747; /* Green on hover */
            color: #FCD116; /* Gold text */
            transform: skewX(5deg) scale(1.02); /* Reverse skew and slight scale */
            opacity: 1;
        }

        /* Styling for Role Matching Container */
        #role-matching-challenge-container {
            background-color: #F0F8FF; /* AliceBlue background for contrast */
            border: 6px double #006747; /* Double green border */
            padding: 30px;
            margin-top: 50px;
            margin-bottom: 50px;
            border-radius: 20px;
            box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; /* Gold and Red offset shadows */
            font-size: 1.2em;
            color: #333333;
            text-align: center;
            position: relative; /* For overlapping and positioning */
            left: 15px; /* Intentionally offset */
            transform: rotate(4deg); /* Significant tilt */
            z-index: 5; /* Highest z-index to be most prominent */
            animation: pulse-shadow 3s infinite alternate;
        }

        @keyframes pulse-shadow {
            0% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
            50% { box-shadow: -15px -15px 0px 0px rgba(0,0,0,0.5), 15px 15px 0px 0px rgba(0,0,0,0.5); }
            100% { box-shadow: -12px -12px 0px 0px #FCD116, 12px 12px 0px 0px #FF0000; }
        }

        #role-matching-challenge-container h3 {
            color: #006747;
            margin-top: 0;
            margin-bottom: 25px;
            font-size: 1.6em;
            text-shadow: 2px 2px 0px #FCD116;
            font-family: 'Impact', sans-serif; /* Aggressive font */
            line-height: 1.3;
        }

        .role-matching-grid {
            display: grid;
            grid-template-columns: repeat(2, 1fr); /* 2 columns to make it more spread out */
            gap: 25px; /* Large gap */
            margin-top: 30px;
            margin-bottom: 30px;
            border: 3px ridge #FCD116; /* Ridge border */
            padding: 20px;
            background-color: #FAFAF0; /* Very light yellow */
            box-shadow: inset 0 0 10px rgba(0, 103, 71, 0.2);
            transform: skewY(1deg); /* Slight skew to the grid itself */
        }

        .person-card {
            border: 2px dashed #006747; /* Dashed green border */
            padding: 15px;
            background-color: #FFFFFF;
            box-shadow: 5px 5px 8px rgba(0, 0, 0, 0.15);
            text-align: center;
            transition: transform 0.3s ease-in-out;
            transform: rotate(calc(var(--rotation-deg) * 1deg)); /* Variable rotation for each card */
            position: relative;
        }

        .person-card:nth-child(odd) { --rotation-deg: -2; }
        .person-card:nth-child(even) { --rotation-deg: 2; }

        .person-card:hover {
            transform: scale(1.05) rotate(0deg); /* Straighten and zoom on hover */
            box-shadow: 0 0 15px #FCD116;
            border-color: #FCD116; /* Gold border on hover */
        }

        .person-card img {
            width: 100%;
            max-width: 150px; /* Consistent image size */
            height: 150px;
            object-fit: cover;
            border: 3px solid #FCD116; /* Gold border for image */
            border-radius: 50%; /* Make images circular */
            margin-bottom: 15px;
            filter: saturate(150%); /* Over-saturated images */
            animation: image-glow 2s infinite alternate;
        }

        @keyframes image-glow {
            0% { box-shadow: 0 0 5px #FCD116; }
            100% { box-shadow: 0 0 15px #FCD116, 0 0 20px #006747; }
        }

        .role-select {
            width: 80%;
            padding: 10px;
            margin-top: 10px;
            border: 2px solid #006747; /* Green border */
            border-radius: 5px;
            background-color: #E6FFE6; /* Light green background */
            font-size: 1em;
            font-family: 'Courier New', monospace; /* Annoying font for dropdown */
            color: #003300;
            cursor: pointer;
            appearance: none; /* Remove default arrow */
            background-image: url('data:image/svg+xml;charset=US-ASCII,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%22292.4%22%20height%3D%22292.4%22%3E%3Cpath%20fill%3D%22%23006747%22%20d%3D%22M287%2069.9a14.6%2014.6%200%200%200-20.7%200L146.2%20189.9%2026.1%2069.9a14.6%2014.6%200%200%200-20.7%2020.7l130.8%20130.9a14.6%2014.6%200%200%200%2020.7%200L287%2090.6a14.6%2014.6%200%200%200%200-20.7z%22%2F%3E%3C%2Fsvg%3E');
            background-repeat: no-repeat;
            background-position: right 10px top 50%;
            background-size: 16px;
            padding-right: 30px; /* Space for custom arrow */
        }

        .role-select:focus {
            outline: none;
            border-color: #FCD116;
            box-shadow: 0 0 0 3px rgba(252, 209, 22, 0.5);
        }

        #verify-role-btn {
            background-color: #006747; /* Green button */
            color: #FCD116; /* Gold text */
            padding: 20px 40px;
            border: 3px solid #FCD116; /* Gold border */
            border-radius: 10px;
            font-size: 1.3em;
            font-weight: bold;
            margin-top: 30px;
            width: auto;
            cursor: not-allowed; /* Initially disabled visually */
            opacity: 0.7;
            transition: all 0.4s ease;
            transform: rotate(-5deg); /* Another annoying tilt */
            letter-spacing: 2px; /* Spaced out text */
        }

        #verify-role-btn:hover {
            background-color: #FCD116; /* Gold on hover */
            color: #006747; /* Green text */
            transform: rotate(5deg) scale(1.03); /* Reverse tilt and scale */
            opacity: 1;
            box-shadow: 0 0 20px rgba(0, 103, 71, 0.7);
        }

        /* Validation feedback styles */
        .requirement-met {
            color: green !important;
            text-decoration: line-through;
            opacity: 0.7;
        }

        .requirement-not-met {
            color: red !important;
            font-weight: bold;
            animation: shake 0.5s;
        }

        @keyframes shake {
            0% { transform: translateX(0); }
            25% { transform: translateX(-5px); }
            50% { transform: translateX(5px); }
            75% { transform: translateX(-5px); }
            100% { transform: translateX(0); }
        }

    </style>
</head>
<body>
    <div class="login-container">
        <h1>Login to USF (Unbearably Slow & Frustrating)</h1>
        <form id="login-form" action="#" method="POST">
            <div class="form-group">
                <label for="username">Enter Your Highly Secret Username:</label>
                <input type="text" id="username" name="username" placeholder="e.g., student-ID-007">
            </div>
            <div class="form-group">
                <label for="password">Your Insecure Password Goes Here:</label>
                <input type="password" id="password" name="password" placeholder="e.g., pa$$word123">
            </div>

            <div id="login-requirements-container">
                <h3>Important! Read ALL Password Requirements Carefully:</h3>
                <ul id="password-requirements-list">
                    <li id="req-digit">At least one digit must be included.</li>
                    <li id="req-lowercase">At least one lowercase character is required.</li>
                    <li id="req-special">At least one special character (!@#$%^&*) is mandatory.</li>
                    <li id="req-uppercase">At least one uppercase character is required.</li>
                    <li id="req-minlength">Minimum length of 12 characters is enforced.</li>
                    <li id="req-dictionary">Must not contain common dictionary words.</li>
                    <li id="req-username">Must not contain your username.</li>
                    <li id="req-sequential">No sequential characters (e.g., 'abc', '123').</li>
                    <li id="req-history">Password history check: Must be different from the last 10 passwords.</li>
                </ul>
            </div>

            <div id="captcha-challenge-container">
                <h3>Prove you are not a robot (or a very bored USF student) by selecting all images containing a single-celled organism riding a unicycle:</h3>
                <div class="captcha-grid">
                    <div class="captcha-item">
                        <input type="checkbox" id="img1" name="captcha-img" value="img1">
                        <img src="https://picsum.photos/id/60/150/150" alt="Abstract Image 1">
                        <label for="img1" style="display:none;">Select Image 1</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img2" name="captcha-img" value="img2">
                        <img src="https://picsum.photos/id/61/150/150" alt="Abstract Image 2">
                        <label for="img2" style="display:none;">Select Image 2</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img3" name="captcha-img" value="img3">
                        <img src="https://picsum.photos/id/62/150/150" alt="Abstract Image 3">
                        <label for="img3" style="display:none;">Select Image 3</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img4" name="captcha-img" value="img4">
                        <img src="https://picsum.photos/id/63/150/150" alt="Abstract Image 4">
                        <label for="img4" style="display:none;">Select Image 4</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img5" name="captcha-img" value="img5">
                        <img src="https://picsum.photos/id/64/150/150" alt="Abstract Image 5">
                        <label for="img5" style="display:none;">Select Image 5</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img6" name="captcha-img" value="img6">
                        <img src="https://picsum.photos/id/65/150/150" alt="Abstract Image 6">
                        <label for="img6" style="display:none;">Select Image 6</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img7" name="captcha-img" value="img7">
                        <img src="https://picsum.photos/id/66/150/150" alt="Abstract Image 7">
                        <label for="img7" style="display:none;">Select Image 7</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img8" name="captcha-img" value="img8">
                        <img src="https://picsum.photos/id/67/150/150" alt="Abstract Image 8">
                        <label for="img8" style="display:none;">Select Image 8</label>
                    </div>
                    <div class="captcha-item">
                        <input type="checkbox" id="img9" name="captcha-img" value="img9">
                        <img src="https://picsum.photos/id/68/150/150" alt="Abstract Image 9">
                        <label for="img9" style="display:none;">Select Image 9</label>
                    </div>
                </div>
                <button type="button" id="verify-captcha-btn">Verify Captcha (Good Luck!)</button>
            </div>

            <div id="role-matching-challenge-container">
                <h3>Match the individual to their highly classified USF role. Misclicking will result in academic probation!</h3>
                <div class="role-matching-grid">
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1005/150/150" alt="Person 1">
                        <select class="role-select" id="person1-role" name="person1-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1011/150/150" alt="Person 2">
                        <select class="role-select" id="person2-role" name="person2-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1025/150/150" alt="Person 3">
                        <select class="role-select" id="person3-role" name="person3-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                    <div class="person-card">
                        <img src="https://picsum.photos/id/1027/150/150" alt="Person 4">
                        <select class="role-select" id="person4-role" name="person4-role">
                            <option value="">Select Role...</option>
                            <option value="student">Student</option>
                            <option value="professor">Professor</option>
                            <option value="alumni">Alumni</option>
                            <option value="staff">Staff</option>
                        </select>
                    </div>
                </div>
                <button type="button" id="verify-role-btn">Verify Role Matches</button>
            </div>

            <button type="submit" id="final-login-btn">Proceed With Caution</button>
        </form>
    </div>

    <script>
        // Global flags for challenge completion
        let isCaptchaVerified = false;
        let isRoleMatchingVerified = false;

        // 1. Get references to all necessary HTML elements
        const loginForm = document.getElementById('login-form');
        const usernameInput = document.getElementById('username');
        const passwordInput = document.getElementById('password');
        const passwordRequirementsList = document.getElementById('password-requirements-list');
        const requirementItems = {
            digit: document.getElementById('req-digit'),
            lowercase: document.getElementById('req-lowercase'),
            special: document.getElementById('req-special'),
            uppercase: document.getElementById('req-uppercase'),
            minlength: document.getElementById('req-minlength'),
            dictionary: document.getElementById('req-dictionary'),
            username: document.getElementById('req-username'),
            sequential: document.getElementById('req-sequential'),
            history: document.getElementById('req-history')
        };

        const captchaGrid = document.querySelector('.captcha-grid');
        const captchaCheckboxes = document.querySelectorAll('.captcha-item input[type="checkbox"]');
        const verifyCaptchaBtn = document.getElementById('verify-captcha-btn');

        const roleMatchingGrid = document.querySelector('.role-matching-grid');
        const roleSelects = document.querySelectorAll('.role-select');
        const verifyRoleBtn = document.getElementById('verify-role-btn');

        const finalLoginBtn = document.getElementById('final-login-btn');

        // 2. Implement a JavaScript function for username and password validation
        function validatePassword() {
            const username = usernameInput.value;
            const password = passwordInput.value;
            let allRequirementsMet = true;

            // Helper to update requirement item style
            const updateRequirement = (item, condition) => {
                if (condition) {
                    item.classList.remove('requirement-not-met');
                    item.classList.add('requirement-met');
                } else {
                    item.classList.remove('requirement-met');
                    item.classList.add('requirement-not-met');
                    allRequirementsMet = false;
                }
            };

            // At least one digit
            updateRequirement(requirementItems.digit, /\\d/.test(password));
            // At least one lowercase character
            updateRequirement(requirementItems.lowercase, /[a-z]/.test(password));
            // At least one special character
            updateRequirement(requirementItems.special, /[!@#$%^&*]/.test(password));
            // At least one uppercase character
            updateRequirement(requirementItems.uppercase, /[A-Z]/.test(password));
            // Minimum length of 12 characters
            updateRequirement(requirementItems.minlength, password.length >= 12);
            // Must not contain common dictionary words (simplified)
            const commonWords = ['password', '123456', 'qwerty', username]; // Add more words as needed
            let containsCommonWord = false;
            for (let word of commonWords) {
                if (password.toLowerCase().includes(word.toLowerCase())) {
                    containsCommonWord = true;
                    break;
                }
            }
            updateRequirement(requirementItems.dictionary, !containsCommonWord);
            // Must not contain your username
            updateRequirement(requirementItems.username, !password.toLowerCase().includes(username.toLowerCase()) || username === '');
            // No sequential characters (simplified for 'abc', '123')
            const isSequential = /(abc|bcd|cde|def|efg|fgh|ghi|hij|ijk|jkl|klm|lmn|mno|nop|opq|pqr|qrs|rst|stu|tuv|uvw|vwx|wxy|xyz)|(012|123|234|345|456|567|678|789)/.test(password);
            updateRequirement(requirementItems.sequential, !isSequential);
            // Password history check: Must be different from the last 10 passwords (client-side simulation)
            // For simplicity, we'll just check if it's 'oldpassword1' (dummy history)
            updateRequirement(requirementItems.history, password !== 'oldpassword1');

            return allRequirementsMet;
        }

        // Add event listener for password input to trigger validation
        passwordInput.addEventListener('input', validatePassword);

        // 3. Add an event listener to the captcha-grid to handle clicks on captcha images/checkboxes.
        captchaGrid.addEventListener('change', (event) => {
            if (event.target.type === 'checkbox') {
                const captchaItem = event.target.closest('.captcha-item');
                if (event.target.checked) {
                    captchaItem.classList.add('selected');
                } else {
                    captchaItem.classList.remove('selected');
                }
            }
        });

        // 4. Implement a JavaScript function for the image captcha verification.
        function verifyCaptcha() {
            const selectedImages = Array.from(captchaCheckboxes).filter(cb => cb.checked).map(cb => cb.id);
            // Predefined 'correct' images: img1, img5, img9
            const correctSelections = ['img1', 'img5', 'img9'];

            const isCorrect = correctSelections.every(imgId => selectedImages.includes(imgId)) &&
                              selectedImages.length === correctSelections.length;

            if (isCorrect) {
                isCaptchaVerified = true;
                verifyCaptchaBtn.textContent = 'Captcha VERIFIED! Finally!';
                verifyCaptchaBtn.style.backgroundColor = '#006747'; // Green
                verifyCaptchaBtn.style.color = '#FCD116'; // Gold text
                verifyCaptchaBtn.style.cursor = 'not-allowed';
                verifyCaptchaBtn.disabled = true;
                alert('Image Captcha successfully solved! (But was it really?)');
            } else {
                isCaptchaVerified = false;
                verifyCaptchaBtn.textContent = 'Captcha FAILED! Try again. Or don\'t.';
                verifyCaptchaBtn.style.backgroundColor = '#FF0000'; // Red
                verifyCaptchaBtn.style.color = 'white';
                verifyCaptchaBtn.style.cursor = 'pointer';
                verifyCaptchaBtn.disabled = false;
                alert('Incorrect Captcha selections. The unicycle-riding single-celled organisms are displeased.');
                // Optionally, clear selections or shuffle images for added annoyance
            }
            return isCaptchaVerified;
        }
        verifyCaptchaBtn.addEventListener('click', verifyCaptcha);

        // 5. Implement a JavaScript function for the person role matching verification.
        function verifyRoleMatching() {
            // Predefined correct role assignments: Person 1: Student, Person 2: Professor, Person 3: Staff, Person 4: Alumni
            const correctAssignments = {
                'person1-role': 'student',
                'person2-role': 'professor',
                'person3-role': 'staff',
                'person4-role': 'alumni'
            };

            let allRolesCorrect = true;
            roleSelects.forEach(select => {
                if (select.value !== correctAssignments[select.id]) {
                    allRolesCorrect = false;
                    // Annoying visual feedback for incorrect selections
                    select.style.borderColor = 'red';
                    select.style.boxShadow = '0 0 10px red';
                } else {
                    select.style.borderColor = '#006747';
                    select.style.boxShadow = '0 0 0 3px rgba(0, 103, 71, 0.5)';
                }
            });

            if (allRolesCorrect) {
                isRoleMatchingVerified = true;
                verifyRoleBtn.textContent = 'Roles MATCHED! Amazing!';
                verifyRoleBtn.style.backgroundColor = '#006747'; // Green
                verifyRoleBtn.style.color = '#FCD116'; // Gold
                verifyRoleBtn.style.cursor = 'not-allowed';
                verifyRoleBtn.disabled = true;
                alert('Role Matching Challenge Passed! Your intuition is unnerving.');
            } else {
                isRoleMatchingVerified = false;
                verifyRoleBtn.textContent = 'Role Mismatch Detected! Re-evaluate careers.';
                verifyRoleBtn.style.backgroundColor = '#FF0000'; // Red
                verifyRoleBtn.style.color = 'white';
                verifyRoleBtn.style.cursor = 'pointer';
                verifyRoleBtn.disabled = false;
                alert('Some roles are incorrect. The HR department has been notified.');
            }
            return isRoleMatchingVerified;
        }
        verifyRoleBtn.addEventListener('click', verifyRoleMatching);

        // 6. Add an event listener to the main login form\'s submit button.
        loginForm.addEventListener('submit', (event) => {
            event.preventDefault(); // Prevent default form submission

            // Validate all conditions
            const passwordValid = validatePassword();

            if (passwordValid && isCaptchaVerified && isRoleMatchingVerified) {
                alert('Congratulations! You\'ve navigated our impossible login. Just kidding, no actual login functionality here, this is a demo! Feel free to refresh.');
            } else {
                let errorMessage = 'Login Failed. The system requires perfection!\n\n';
                if (!passwordValid) {
                    errorMessage += '- Password does not meet all requirements.\n';
                }
                if (!isCaptchaVerified) {
                    errorMessage += '- Image Captcha not verified or incorrect.\n';
                }
                if (!isRoleMatchingVerified) {
                    errorMessage += '- Person Role Matching not verified or incorrect.\n';
                }
                alert(errorMessage + '\nDo not give up now!');
            }
        });

        // Initial password validation on load (in case there\'s pre-filled data)
        validatePassword();
    </script>
</body>
</html>
'''

from IPython.display import HTML
display(HTML(html_content))

print("HTML content with integrated JavaScript login logic, validation, and interactivity displayed.")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Annoying USF Login</title>
#     <style>
#         body {
#             font-family: 'Times New Roman', serif; /* Slightly formal and inconsistent */
#             background-color: #f8f8f8; /* Off-white background */
#             color: #006747; /* USF Green as primary text color */
#             margin: 0;
#             padding: 20px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh; /* Ensure full viewport height */
#             overflow: hidden; /* To prevent scrollbar from minor rotations */
#         }
#
#         .login-container {
#             background-color: #ffffff; /* White background for the container */
#             border: 5px solid #FCD116; /* USF Gold border */
#             border-radius: 0px; /* Sharp edges */
# ...

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide the complete HTML, CSS, and JavaScript code for the annoying, funny, and over-complicated USF Class Registration login page, ensuring all specified features are included and the user can eventually 'log in'.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Comprehensive HTML Structure Established:** The foundational HTML structure for the USF Class Registration login page was successfully created, including dedicated sections for username/password input, login requirements, image captcha, and a person role matching challenge.
# *   **"Annoying" and USF-Themed CSS Styling Applied:** The page was extensively styled using the specified green, gold, and white color scheme. The styling incorporated numerous intentionally cumbersome and annoying elements such as inconsistent font families, a slightly tilted and off-center login container with offset shadows, floating labels and input fields, large padding and margins, flashing focus effects on inputs, a subtly flashing background pattern, and dynamic, distracting button hover effects.
# *   **Obstructive Alphabetical Login Requirements Implemented:** A prominent section detailing password requirements was added. These requirements are displayed in an alphabetically ordered list with a bright red pulsating border, a strong box-shadow, a slight rotation, and individual list items styled with "Comic Sans MS" font and animated spinning "🚨" bullet points, ensuring they are visually obstructive.
# *   **Over-Complicated Image Captcha Developed:** An image captcha component was integrated, featuring an absurd question ("Select all images containing a single-celled organism riding a unicycle") and a grid of placeholder images with checkboxes. The captcha container itself wiggles, and individual image selections have dynamic visual feedback. The verification button is initially disabled and has a jarring skewed appearance.
# *   **Person Role Matching Authentication Challenge Integrated:** A second complex authentication challenge was added, requiring users to match images of people to their "highly classified USF roles" via dropdowns. This section is designed to be highly prominent with a double green border, gold and red offset box-shadows, a significant tilt, and a pulsating shadow animation. Images are circular and oversaturated, and dropdowns use an "annoying" font.
# *   **Robust Client-Side JavaScript Logic Implemented:** Comprehensive JavaScript was added to orchestrate the entire login process. This includes:
#     *   **Dynamic Password Validation:** Real-time client-side validation of password strength against multiple criteria (length, character types, common words, username, sequential characters, and simulated history) with instant visual feedback on each requirement (toggling green/red styling and "shake" animation).
#     *   **Interactive Captcha Verification:** Logic to check selected image checkboxes against a predefined correct set, updating a global flag and providing clear success/failure alerts and visual cues on the verification button.
#     *   **Role Matching Challenge Verification:** Logic to evaluate dropdown selections against predefined correct roles, updating a global flag and providing alerts and visual feedback on correct/incorrect choices.
#     *   **Unified Login Gateway:** The final "Proceed With Caution" button is only enabled if all password requirements are met, and both the image captcha and role matching challenges are successfully completed, preventing submission otherwise and providing detailed error messages.
# *   **Technical Issue Resolution:** A `SyntaxWarning` encountered during Python's interpretation of JavaScript regular expressions (`\d`) within multiline strings was successfully identified and resolved by correctly escaping the backslash.
#
# ### Insights or Next Steps
#
# *   **Enhance "Annoyance" with Dynamic Content:** To further the "over-complicated" aspect, consider implementing JavaScript to dynamically shuffle captcha images and roles for the matching challenge upon page load or failed attempts, or periodically change the password requirements.
# *   **Integrate Accessibility Barriers:** For a truly annoying experience, consider adding subtle, non-standard accessibility barriers (e.g., extremely low contrast text, unskippable animations, non-standard tab orders) while ensuring it technically remains a functional web page, pushing the boundaries of user frustration design.
